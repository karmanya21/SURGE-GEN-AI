# %% [markdown]
# # Drug Molecule Generation with VAE
#
# **Author:** [Victor Basu](https://www.linkedin.com/in/victor-basu-520958147)<br>
# **Date created:** 2022/03/10<br>
# **Last modified:** 2024/12/17<br>
# **Description:** Implementing a Convolutional Variational AutoEncoder (VAE) for Drug Discovery.

# %% [markdown]
# ## Introduction
#
# In this example, we use a Variational Autoencoder to generate molecules for drug discovery.
# We use the research papers
# [Automatic chemical design using a data-driven continuous representation of molecules](https://arxiv.org/abs/1610.02415)
# and [MolGAN: An implicit generative model for small molecular graphs](https://arxiv.org/abs/1805.11973)
# as a reference.
#
# The model described in the paper **Automatic chemical design using a data-driven
# continuous representation of molecules** generates new molecules via efficient exploration
# of open-ended spaces of chemical compounds. The model consists of
# three components: Encoder, Decoder and Predictor. The Encoder converts the discrete
# representation of a molecule into a real-valued continuous vector, and the Decoder
# converts these continuous vectors back to discrete molecule representations. The
# Predictor estimates chemical properties from the latent continuous vector representation
# of the molecule. Continuous representations allow the use of gradient-based
# optimization to efficiently guide the search for optimized functional compounds.
#
# ![intro](https://bit.ly/3CtPMzM)
#
# **Figure (a)** - A diagram of the autoencoder used for molecule design, including the
# joint property prediction model. Starting from a discrete molecule representation, such
# as a SMILES string, the encoder network converts each molecule into a vector in the
# latent space, which is effectively a continuous molecule representation. Given a point
# in the latent space, the decoder network produces a corresponding SMILES string. A
# multilayer perceptron network estimates the value of target properties associated with
# each molecule.
#
# **Figure (b)** - Gradient-based optimization in continuous latent space. After training a
# surrogate model `f(z)` to predict the properties of molecules based on their latent
# representation `z`, we can optimize `f(z)` with respect to `z` to find new latent
# representations expected to match specific desired properties. These new latent
# representations can then be decoded into SMILES strings, at which point their properties
# can be tested empirically.
#
# For an explanation and implementation of MolGAN, please refer to the Keras Example
# [**WGAN-GP with R-GCN for the generation of small molecular graphs**](https://bit.ly/3pU6zXK) by
# Alexander Kensert. Many of the functions used in the present example are from the above Keras example.

# %% [markdown]
# ## Setup
#
# RDKit is an open source toolkit for cheminformatics and machine learning. This toolkit come in handy
# if one is into drug discovery domain. In this example, RDKit is used to conveniently
# and efficiently transform SMILES to molecule objects, and then from those obtain sets of atoms
# and bonds.
#
# Quoting from
# [WGAN-GP with R-GCN for the generation of small molecular graphs](https://keras.io/examples/generative/wgan-graphs/)):
#
# **"SMILES expresses the structure of a given molecule in the form of an ASCII string.
# The SMILES string is a compact encoding which, for smaller molecules, is relatively human-readable.
# Encoding molecules as a string both alleviates and facilitates database and/or web searching
# of a given molecule. RDKit uses algorithms to accurately transform a given SMILES to
# a molecule object, which can then be used to compute a great number of molecular properties/features."**

# %%
pip install rdkit==2022.9.5
# Out:
# Requirement already satisfied: rdkit==2022.9.5 in /usr/local/lib/python3.11/dist-packages (2022.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit==2022.9.5) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit==2022.9.5) (11.2.1)

# %%
import pandas as pd

# %%
pip install "numpy<2.0"
# Out:
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import ast

import numpy as np

import tensorflow as tf
import keras
from keras import layers
from keras import ops

import matplotlib.pyplot as plt
from rdkit import Chem, RDLogger
from rdkit.Chem import BondType
from rdkit.Chem.Draw import MolsToGridImage

RDLogger.DisableLog("rdApp.*")

# %%
pip install torch_geometric rdkit
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (2022.9.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.6.15)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.7 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
from torch_geometric.datasets import QM9
from rdkit import Chem
import pandas as pd

# Load QM9 dataset
dataset = QM9(root='qm9/')
smiles_list = dataset.smiles

target_index = 0  # Dipole moment
all_data = []

for i, data in enumerate(dataset):
    smiles = smiles_list[i]
    mol = Chem.MolFromSmiles(smiles)

    if mol is not None:
        dipole_moment = data.y[0][target_index].item()
        all_data.append((smiles, dipole_moment))

# Store in DataFrame
df = pd.DataFrame(all_data, columns=["SMILES", "DipoleMoment"])

# Preview
print(df.head())
print(df.tail())
# Out:
# Downloading https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/molnet_publish/qm9.zip
# Extracting qm9/raw/qm9.zip
# Downloading https://ndownloader.figshare.com/files/3195404
# Processing...
# 100%|██████████| 133885/133885 [02:10<00:00, 1025.50it/s]
# Done!
#               SMILES  DipoleMoment
# 0  [H]C([H])([H])[H]        0.0000
# 1       [H]N([H])[H]        1.6256
# 2            [H]O[H]        1.8511
# 3          [H]C#C[H]        0.0000
# 4             [H]C#N        2.8937
#                                                    SMILES  DipoleMoment
# 129423  [H]C1([H])[C@@]23[N@H+]4[C@@]5([H])[C@]1([H])[...        1.4529
# 129424  [H]C1([H])[C@@]2([H])[C@@]3([H])[C@@]14O[C@]1(...        1.3774
# 129425  [H]C1([H])[N@@H+]2[C@@]3([H])[C@]2([H])[C@]2([...        1.2480
# 129426  [H]C1([H])[N@H+]2[C@@]3([H])[C@@]14C([H])([H])...        1.9576
# 129427  [H]C1([H])[N@H+]2[C@@]3([H])[C@@]14O[C@@]1([H]...        0.8626

# %%
df["SMILES"][1110]
# Out:
# '[H]O[C@]1(C([H])([H])[H])C([H])([H])[C@@]1(O[H])C([H])([H])[H]'

# %% [markdown]
# ## Dataset
#
# We use the [**ZINC – A Free Database of Commercially Available Compounds for
# Virtual Screening**](https://bit.ly/3IVBI4x) dataset. The dataset comes with molecule
# formula in SMILE representation along with their respective molecular properties such as
# **logP** (water–octanal partition coefficient), **SAS** (synthetic
# accessibility score) and **QED** (Qualitative Estimate of Drug-likeness).

# %% [markdown]
# ## Hyperparameters

# %%
import ast
from rdkit import Chem
from rdkit.Chem.rdchem import BondType

# Clean up SMILES column
df["SMILES"] = df["SMILES"].astype(str).apply(lambda s: s.replace("\n", "").strip())

# Compute MAX_MOLSIZE (based on SMILES length)
MAX_MOLSIZE = max(df["SMILES"].str.len())

# Build charset from unique atoms
unique_atoms = set()
max_atoms = 0  # Initialize max atom count

for smi in df["SMILES"]:
    mol = Chem.MolFromSmiles(smi)
    if mol:
        atoms = mol.GetAtoms()
        max_atoms = max(max_atoms, len(atoms))  # Track maximum number of atoms
        for atom in atoms:
            unique_atoms.add(atom.GetSymbol())

# Handle multi-character atoms
SMILE_CHARSET = sorted(list(unique_atoms))

# Rebuild mappings
SMILE_to_index = {c: i for i, c in enumerate(SMILE_CHARSET)}
index_to_SMILE = {i: c for i, c in enumerate(SMILE_CHARSET)}
atom_mapping = dict(SMILE_to_index)
atom_mapping.update(index_to_SMILE)

# Bond type mapping
bond_mapping = {
    "SINGLE": 0, "DOUBLE": 1, "TRIPLE": 2, "AROMATIC": 3,
    0: BondType.SINGLE,
    1: BondType.DOUBLE,
    2: BondType.TRIPLE,
    3: BondType.AROMATIC
}

# Constants
BATCH_SIZE = 100
EPOCHS = 10
VAE_LR = 5e-4

NUM_ATOMS = max_atoms  # Dynamically determined
MAX_ATOMS = max_atoms  # Dynamically determined
MAX_SAMPLES = 129427  # Optional: limit on number of molecules to use
ATOM_DIM = len(SMILE_CHARSET) + 1
BOND_DIM = 4 + 1  # 4 bond types + 1 padding
LATENT_DIM = 435

# %%
ATOM_DIM
# Out:
# 6

# %%
MAX_SAMPLES = 129427

# %%
MAX_ATOMS
# Out:
# 12

# %%
SMILE_CHARSET
# Out:
# ['C', 'F', 'H', 'N', 'O']

# %%
# SMILE_CHARSET = '["C", "B", "F", "I", "H", "O", "N", "S", "P", "Cl", "Br"]'

# bond_mapping = {"SINGLE": 0, "DOUBLE": 1, "TRIPLE": 2, "AROMATIC": 3}
# bond_mapping.update(
#     {0: BondType.SINGLE, 1: BondType.DOUBLE, 2: BondType.TRIPLE, 3: BondType.AROMATIC}
# )
# SMILE_CHARSET = ast.literal_eval(SMILE_CHARSET)

# MAX_MOLSIZE = max(df["smiles"].str.len())
# SMILE_to_index = dict((c, i) for i, c in enumerate(SMILE_CHARSET))
# index_to_SMILE = dict((i, c) for i, c in enumerate(SMILE_CHARSET))
# atom_mapping = dict(SMILE_to_index)
# atom_mapping.update(index_to_SMILE)

# BATCH_SIZE = 100
# EPOCHS = 10

# VAE_LR = 5e-4
# NUM_ATOMS = 120  # Maximum number of atoms

# ATOM_DIM = len(SMILE_CHARSET)  # Number of atom types
# BOND_DIM = 4 + 1  # Number of bond types
# LATENT_DIM = 435  # Size of the latent space


def smiles_to_graph(smiles):
    # Converts SMILES to molecule object
    molecule = Chem.MolFromSmiles(smiles)

    # Initialize adjacency and feature tensor
    adjacency = np.zeros((BOND_DIM, NUM_ATOMS, NUM_ATOMS), "float32")
    features = np.zeros((NUM_ATOMS, ATOM_DIM), "float32")

    # loop over each atom in molecule
    for atom in molecule.GetAtoms():
        i = atom.GetIdx()
        atom_type = atom_mapping[atom.GetSymbol()]
        features[i] = np.eye(ATOM_DIM)[atom_type]
        # loop over one-hop neighbors
        for neighbor in atom.GetNeighbors():
            j = neighbor.GetIdx()
            bond = molecule.GetBondBetweenAtoms(i, j)
            bond_type_idx = bond_mapping[bond.GetBondType().name]
            adjacency[bond_type_idx, [i, j], [j, i]] = 1

    # Where no bond, add 1 to last channel (indicating "non-bond")
    # Notice: channels-first
    adjacency[-1, np.sum(adjacency, axis=0) == 0] = 1

    # Where no atom, add 1 to last column (indicating "non-atom")
    features[np.where(np.sum(features, axis=1) == 0)[0], -1] = 1

    return adjacency, features


def graph_to_molecule(graph):
    # Unpack graph
    adjacency, features = graph

    # RWMol is a molecule object intended to be edited
    molecule = Chem.RWMol()

    # Remove "no atoms" & atoms with no bonds
    keep_idx = np.where(
        (np.argmax(features, axis=1) != ATOM_DIM - 1)
        & (np.sum(adjacency[:-1], axis=(0, 1)) != 0)
    )[0]
    features = features[keep_idx]
    adjacency = adjacency[:, keep_idx, :][:, :, keep_idx]

    # Add atoms to molecule
    for atom_type_idx in np.argmax(features, axis=1):
        atom = Chem.Atom(atom_mapping[atom_type_idx])
        _ = molecule.AddAtom(atom)

    # Add bonds between atoms in molecule; based on the upper triangles
    # of the [symmetric] adjacency tensor
    (bonds_ij, atoms_i, atoms_j) = np.where(np.triu(adjacency) == 1)
    for bond_ij, atom_i, atom_j in zip(bonds_ij, atoms_i, atoms_j):
        if atom_i == atom_j or bond_ij == BOND_DIM - 1:
            continue
        bond_type = bond_mapping[bond_ij]
        molecule.AddBond(int(atom_i), int(atom_j), bond_type)

    # Sanitize the molecule; for more information on sanitization, see
    # https://www.rdkit.org/docs/RDKit_Book.html#molecular-sanitization
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    # Let's be strict. If sanitization fails, return None
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        return None

    return molecule

# %% [markdown]
# ##  Generate training set

# %%
adjacency_tensor, feature_tensor, DipoleMoment_tensor = [], [], []

for idx in range(len(df)):
    if len(adjacency_tensor) >= MAX_SAMPLES:
        break

    smiles = df.loc[idx]["SMILES"]
    DipoleMoment = df.loc[idx]["DipoleMoment"]

    try:
        adjacency, features = smiles_to_graph(smiles)

        if features.shape[0] > MAX_ATOMS:
            continue  # Skip large molecules

        # Pad to fixed size
        padded_adj = np.zeros((adjacency.shape[0], MAX_ATOMS, MAX_ATOMS), dtype=np.float32)
        padded_feat = np.zeros((MAX_ATOMS, features.shape[1]), dtype=np.float32)

        num_atoms = features.shape[0]
        padded_adj[:, :num_atoms, :num_atoms] = adjacency
        padded_feat[:num_atoms] = features

        adjacency_tensor.append(padded_adj)
        feature_tensor.append(padded_feat)
        DipoleMoment_tensor.append(DipoleMoment)

        if len(adjacency_tensor) % 100 == 0:
            print(f"Processed {len(adjacency_tensor)} molecules...")

    except Exception as e:
        print(f"Skipping idx={idx}, error: {e}")
        continue

adjacency_tensor = np.array(adjacency_tensor)
feature_tensor = np.array(feature_tensor)
DipoleMoment_tensor = np.array(DipoleMoment_tensor)

print("Finished loading data!")
print("Adjacency tensor shape:", adjacency_tensor.shape)
print("Feature tensor shape:", feature_tensor.shape)
print("DipoleMoment tensor shape:", DipoleMoment_tensor.shape)



class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype="float32",
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype="float32",
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = ops.matmul(adjacency, features[:, None])
        # Apply linear transformation
        x = ops.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = ops.sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)
# Out:
# Processed 100 molecules...
# Processed 200 molecules...
# Processed 300 molecules...
# Processed 400 molecules...
# Processed 500 molecules...
# Processed 600 molecules...
# Processed 700 molecules...
# Processed 800 molecules...
# Processed 900 molecules...
# Processed 1000 molecules...
# Processed 1100 molecules...
# Processed 1200 molecules...
# Processed 1300 molecules...
# Processed 1400 molecules...
# Processed 1500 molecules...
# Processed 1600 molecules...
# Processed 1700 molecules...
# Processed 1800 molecules...
# Processed 1900 molecules...
# Processed 2000 molecules...
# Processed 2100 molecules...
# Processed 2200 molecules...
# Processed 2300 molecules...
# Processed 2400 molecules...
# Processed 2500 molecules...
# Processed 2600 molecules...
# Processed 2700 molecules...
# Processed 2800 molecules...
# Processed 2900 molecules...
# Processed 3000 molecules...
# Processed 3100 molecules...
# Processed 3200 molecules...
# Processed 3300 molecules...
# Processed 3400 molecules...
# Processed 3500 molecules...
# Processed 3600 molecules...
# Processed 3700 molecules...
# Processed 3800 molecules...
# Processed 3900 molecules...
# Processed 4000 molecules...
# Processed 4100 molecules...
# Processed 4200 molecules...
# Processed 4300 molecules...
# Processed 4400 molecules...
# Processed 4500 molecules...
# Processed 4600 molecules...
# Processed 4700 molecules...
# Processed 4800 molecules...
# Processed 4900 molecules...
# Processed 5000 molecules...
# Processed 5100 molecules...
# Processed 5200 molecules...
# Processed 5300 molecules...
# Processed 5400 molecules...
# Processed 5500 molecules...
# Processed 5600 molecules...
# Processed 5700 molecules...
# Processed 5800 molecules...
# Processed 5900 molecules...
# Processed 6000 molecules...
# Processed 6100 molecules...
# Processed 6200 molecules...
# Processed 6300 molecules...
# Processed 6400 molecules...
# Processed 6500 molecules...
# Processed 6600 molecules...
# Processed 6700 molecules...
# Processed 6800 molecules...
# Processed 6900 molecules...
# Processed 7000 molecules...
# Processed 7100 molecules...
# Processed 7200 molecules...
# Processed 7300 molecules...
# Processed 7400 molecules...
# Processed 7500 molecules...
# Processed 7600 molecules...
# Processed 7700 molecules...
# Processed 7800 molecules...
# Processed 7900 molecules...
# Processed 8000 molecules...
# Processed 8100 molecules...
# Processed 8200 molecules...
# Processed 8300 molecules...
# Processed 8400 molecules...
# Processed 8500 molecules...
# Processed 8600 molecules...
# Processed 8700 molecules...
# Processed 8800 molecules...
# Processed 8900 molecules...
# Processed 9000 molecules...
# Processed 9100 molecules...
# Processed 9200 molecules...
# Processed 9300 molecules...
# Processed 9400 molecules...
# Processed 9500 molecules...
# Processed 9600 molecules...
# Processed 9700 molecules...
# Processed 9800 molecules...
# Processed 9900 molecules...
# Processed 10000 molecules...
# Processed 10100 molecules...
# Processed 10200 molecules...
# Processed 10300 molecules...
# Processed 10400 molecules...
# Processed 10500 molecules...
# Processed 10600 molecules...
# Processed 10700 molecules...
# Processed 10800 molecules...
# Processed 10900 molecules...
# Processed 11000 molecules...
# Processed 11100 molecules...
# Processed 11200 molecules...
# Processed 11300 molecules...
# Processed 11400 molecules...
# Processed 11500 molecules...
# Processed 11600 molecules...
# Processed 11700 molecules...
# Processed 11800 molecules...
# Processed 11900 molecules...
# Processed 12000 molecules...
# Processed 12100 molecules...
# Processed 12200 molecules...
# Processed 12300 molecules...
# Processed 12400 molecules...
# Processed 12500 molecules...
# Processed 12600 molecules...
# Processed 12700 molecules...
# Processed 12800 molecules...
# Processed 12900 molecules...
# Processed 13000 molecules...
# Processed 13100 molecules...
# Processed 13200 molecules...
# Processed 13300 molecules...
# Processed 13400 molecules...
# Processed 13500 molecules...
# Processed 13600 molecules...
# Processed 13700 molecules...
# Processed 13800 molecules...
# Processed 13900 molecules...
# Processed 14000 molecules...
# Processed 14100 molecules...
# Processed 14200 molecules...
# Processed 14300 molecules...
# Processed 14400 molecules...
# Processed 14500 molecules...
# Processed 14600 molecules...
# Processed 14700 molecules...
# Processed 14800 molecules...
# Processed 14900 molecules...
# Processed 15000 molecules...
# Processed 15100 molecules...
# Processed 15200 molecules...
# Processed 15300 molecules...
# Processed 15400 molecules...
# Processed 15500 molecules...
# Processed 15600 molecules...
# Processed 15700 molecules...
# Processed 15800 molecules...
# Processed 15900 molecules...
# Processed 16000 molecules...
# Processed 16100 molecules...
# Processed 16200 molecules...
# Processed 16300 molecules...
# Processed 16400 molecules...
# Processed 16500 molecules...
# Processed 16600 molecules...
# Processed 16700 molecules...
# Processed 16800 molecules...
# Processed 16900 molecules...
# Processed 17000 molecules...
# Processed 17100 molecules...
# Processed 17200 molecules...
# Processed 17300 molecules...
# Processed 17400 molecules...
# Processed 17500 molecules...
# Processed 17600 molecules...
# Processed 17700 molecules...
# Processed 17800 molecules...
# Processed 17900 molecules...
# Processed 18000 molecules...
# Processed 18100 molecules...
# Processed 18200 molecules...
# Processed 18300 molecules...
# Processed 18400 molecules...
# Processed 18500 molecules...
# Processed 18600 molecules...
# Processed 18700 molecules...
# Processed 18800 molecules...
# Processed 18900 molecules...
# Processed 19000 molecules...
# Processed 19100 molecules...
# Processed 19200 molecules...
# Processed 19300 molecules...
# Processed 19400 molecules...
# Processed 19500 molecules...
# Processed 19600 molecules...
# Processed 19700 molecules...
# Processed 19800 molecules...
# Processed 19900 molecules...
# Processed 20000 molecules...
# Processed 20100 molecules...
# Processed 20200 molecules...
# Processed 20300 molecules...
# Processed 20400 molecules...
# Processed 20500 molecules...
# Processed 20600 molecules...
# Processed 20700 molecules...
# Processed 20800 molecules...
# Processed 20900 molecules...
# Processed 21000 molecules...
# Processed 21100 molecules...
# Processed 21200 molecules...
# Processed 21300 molecules...
# Processed 21400 molecules...
# Processed 21500 molecules...
# Processed 21600 molecules...
# Processed 21700 molecules...
# Processed 21800 molecules...
# Processed 21900 molecules...
# Processed 22000 molecules...
# Processed 22100 molecules...
# Processed 22200 molecules...
# Processed 22300 molecules...
# Processed 22400 molecules...
# Processed 22500 molecules...
# Processed 22600 molecules...
# Processed 22700 molecules...
# Processed 22800 molecules...
# Processed 22900 molecules...
# Processed 23000 molecules...
# Processed 23100 molecules...
# Processed 23200 molecules...
# Processed 23300 molecules...
# Processed 23400 molecules...
# Processed 23500 molecules...
# Processed 23600 molecules...
# Processed 23700 molecules...
# Processed 23800 molecules...
# Processed 23900 molecules...
# Processed 24000 molecules...
# Processed 24100 molecules...
# Processed 24200 molecules...
# Processed 24300 molecules...
# Processed 24400 molecules...
# Processed 24500 molecules...
# Processed 24600 molecules...
# Processed 24700 molecules...
# Processed 24800 molecules...
# Processed 24900 molecules...
# Processed 25000 molecules...
# Processed 25100 molecules...
# Processed 25200 molecules...
# Processed 25300 molecules...
# Processed 25400 molecules...
# Processed 25500 molecules...
# Processed 25600 molecules...
# Processed 25700 molecules...
# Processed 25800 molecules...
# Processed 25900 molecules...
# Processed 26000 molecules...
# Processed 26100 molecules...
# Processed 26200 molecules...
# Processed 26300 molecules...
# Processed 26400 molecules...
# Processed 26500 molecules...
# Processed 26600 molecules...
# Processed 26700 molecules...
# Processed 26800 molecules...
# Processed 26900 molecules...
# Processed 27000 molecules...
# Processed 27100 molecules...
# Processed 27200 molecules...
# Processed 27300 molecules...
# Processed 27400 molecules...
# Processed 27500 molecules...
# Processed 27600 molecules...
# Processed 27700 molecules...
# Processed 27800 molecules...
# Processed 27900 molecules...
# Processed 28000 molecules...
# Processed 28100 molecules...
# Processed 28200 molecules...
# Processed 28300 molecules...
# Processed 28400 molecules...
# Processed 28500 molecules...
# Processed 28600 molecules...
# Processed 28700 molecules...
# Processed 28800 molecules...
# Processed 28900 molecules...
# Processed 29000 molecules...
# Processed 29100 molecules...
# Processed 29200 molecules...
# Processed 29300 molecules...
# Processed 29400 molecules...
# Processed 29500 molecules...
# Processed 29600 molecules...
# Processed 29700 molecules...
# Processed 29800 molecules...
# Processed 29900 molecules...
# Processed 30000 molecules...
# Processed 30100 molecules...
# Processed 30200 molecules...
# Processed 30300 molecules...
# Processed 30400 molecules...
# Processed 30500 molecules...
# Processed 30600 molecules...
# Processed 30700 molecules...
# Processed 30800 molecules...
# Processed 30900 molecules...
# Processed 31000 molecules...
# Processed 31100 molecules...
# Processed 31200 molecules...
# Processed 31300 molecules...
# Processed 31400 molecules...
# Processed 31500 molecules...
# Processed 31600 molecules...
# Processed 31700 molecules...
# Processed 31800 molecules...
# Processed 31900 molecules...
# Processed 32000 molecules...
# Processed 32100 molecules...
# Processed 32200 molecules...
# Processed 32300 molecules...
# Processed 32400 molecules...
# Processed 32500 molecules...
# Processed 32600 molecules...
# Processed 32700 molecules...
# Processed 32800 molecules...
# Processed 32900 molecules...
# Processed 33000 molecules...
# Processed 33100 molecules...
# Processed 33200 molecules...
# Processed 33300 molecules...
# Processed 33400 molecules...
# Processed 33500 molecules...
# Processed 33600 molecules...
# Processed 33700 molecules...
# Processed 33800 molecules...
# Processed 33900 molecules...
# Processed 34000 molecules...
# Processed 34100 molecules...
# Processed 34200 molecules...
# Processed 34300 molecules...
# Processed 34400 molecules...
# Processed 34500 molecules...
# Processed 34600 molecules...
# Processed 34700 molecules...
# Processed 34800 molecules...
# Processed 34900 molecules...
# Processed 35000 molecules...
# Processed 35100 molecules...
# Processed 35200 molecules...
# Processed 35300 molecules...
# Processed 35400 molecules...
# Processed 35500 molecules...
# Processed 35600 molecules...
# Processed 35700 molecules...
# Processed 35800 molecules...
# Processed 35900 molecules...
# Processed 36000 molecules...
# Processed 36100 molecules...
# Processed 36200 molecules...
# Processed 36300 molecules...
# Processed 36400 molecules...
# Processed 36500 molecules...
# Processed 36600 molecules...
# Processed 36700 molecules...
# Processed 36800 molecules...
# Processed 36900 molecules...
# Processed 37000 molecules...
# Processed 37100 molecules...
# Processed 37200 molecules...
# Processed 37300 molecules...
# Processed 37400 molecules...
# Processed 37500 molecules...
# Processed 37600 molecules...
# Processed 37700 molecules...
# Processed 37800 molecules...
# Processed 37900 molecules...
# Processed 38000 molecules...
# Processed 38100 molecules...
# Processed 38200 molecules...
# Processed 38300 molecules...
# Processed 38400 molecules...
# Processed 38500 molecules...
# Processed 38600 molecules...
# Processed 38700 molecules...
# Processed 38800 molecules...
# Processed 38900 molecules...
# Processed 39000 molecules...
# Processed 39100 molecules...
# Processed 39200 molecules...
# Processed 39300 molecules...
# Processed 39400 molecules...
# Processed 39500 molecules...
# Processed 39600 molecules...
# Processed 39700 molecules...
# Processed 39800 molecules...
# Processed 39900 molecules...
# Processed 40000 molecules...
# Processed 40100 molecules...
# Processed 40200 molecules...
# Processed 40300 molecules...
# Processed 40400 molecules...
# Processed 40500 molecules...
# Processed 40600 molecules...
# Processed 40700 molecules...
# Processed 40800 molecules...
# Processed 40900 molecules...
# Processed 41000 molecules...
# Processed 41100 molecules...
# Processed 41200 molecules...
# Processed 41300 molecules...
# Processed 41400 molecules...
# Processed 41500 molecules...
# Processed 41600 molecules...
# Processed 41700 molecules...
# Processed 41800 molecules...
# Processed 41900 molecules...
# Processed 42000 molecules...
# Processed 42100 molecules...
# Processed 42200 molecules...
# Processed 42300 molecules...
# Processed 42400 molecules...
# Processed 42500 molecules...
# Processed 42600 molecules...
# Processed 42700 molecules...
# Processed 42800 molecules...
# Processed 42900 molecules...
# Processed 43000 molecules...
# Processed 43100 molecules...
# Processed 43200 molecules...
# Processed 43300 molecules...
# Processed 43400 molecules...
# Processed 43500 molecules...
# Processed 43600 molecules...
# Processed 43700 molecules...
# Processed 43800 molecules...
# Processed 43900 molecules...
# Processed 44000 molecules...
# Processed 44100 molecules...
# Processed 44200 molecules...
# Processed 44300 molecules...
# Processed 44400 molecules...
# Processed 44500 molecules...
# Processed 44600 molecules...
# Processed 44700 molecules...
# Processed 44800 molecules...
# Processed 44900 molecules...
# Processed 45000 molecules...
# Processed 45100 molecules...
# Processed 45200 molecules...
# Processed 45300 molecules...
# Processed 45400 molecules...
# Processed 45500 molecules...
# Processed 45600 molecules...
# Processed 45700 molecules...
# Processed 45800 molecules...
# Processed 45900 molecules...
# Processed 46000 molecules...
# Processed 46100 molecules...
# Processed 46200 molecules...
# Processed 46300 molecules...
# Processed 46400 molecules...
# Processed 46500 molecules...
# Processed 46600 molecules...
# Processed 46700 molecules...
# Processed 46800 molecules...
# Processed 46900 molecules...
# Processed 47000 molecules...
# Processed 47100 molecules...
# Processed 47200 molecules...
# Processed 47300 molecules...
# Processed 47400 molecules...
# Processed 47500 molecules...
# Processed 47600 molecules...
# Processed 47700 molecules...
# Processed 47800 molecules...
# Processed 47900 molecules...
# Processed 48000 molecules...
# Processed 48100 molecules...
# Processed 48200 molecules...
# Processed 48300 molecules...
# Processed 48400 molecules...
# Processed 48500 molecules...
# Processed 48600 molecules...
# Processed 48700 molecules...
# Processed 48800 molecules...
# Processed 48900 molecules...
# Processed 49000 molecules...
# Processed 49100 molecules...
# Processed 49200 molecules...
# Processed 49300 molecules...
# Processed 49400 molecules...
# Processed 49500 molecules...
# Processed 49600 molecules...
# Processed 49700 molecules...
# Processed 49800 molecules...
# Processed 49900 molecules...
# Processed 50000 molecules...
# Processed 50100 molecules...
# Processed 50200 molecules...
# Processed 50300 molecules...
# Processed 50400 molecules...
# Processed 50500 molecules...
# Processed 50600 molecules...
# Processed 50700 molecules...
# Processed 50800 molecules...
# Processed 50900 molecules...
# Processed 51000 molecules...
# Processed 51100 molecules...
# Processed 51200 molecules...
# Processed 51300 molecules...
# Processed 51400 molecules...
# Processed 51500 molecules...
# Processed 51600 molecules...
# Processed 51700 molecules...
# Processed 51800 molecules...
# Processed 51900 molecules...
# Processed 52000 molecules...
# Processed 52100 molecules...
# Processed 52200 molecules...
# Processed 52300 molecules...
# Processed 52400 molecules...
# Processed 52500 molecules...
# Processed 52600 molecules...
# Processed 52700 molecules...
# Processed 52800 molecules...
# Processed 52900 molecules...
# Processed 53000 molecules...
# Processed 53100 molecules...
# Processed 53200 molecules...
# Processed 53300 molecules...
# Processed 53400 molecules...
# Processed 53500 molecules...
# Processed 53600 molecules...
# Processed 53700 molecules...
# Processed 53800 molecules...
# Processed 53900 molecules...
# Processed 54000 molecules...
# Processed 54100 molecules...
# Processed 54200 molecules...
# Processed 54300 molecules...
# Processed 54400 molecules...
# Processed 54500 molecules...
# Processed 54600 molecules...
# Processed 54700 molecules...
# Processed 54800 molecules...
# Processed 54900 molecules...
# Processed 55000 molecules...
# Processed 55100 molecules...
# Processed 55200 molecules...
# Processed 55300 molecules...
# Processed 55400 molecules...
# Processed 55500 molecules...
# Processed 55600 molecules...
# Processed 55700 molecules...
# Processed 55800 molecules...
# Processed 55900 molecules...
# Processed 56000 molecules...
# Processed 56100 molecules...
# Processed 56200 molecules...
# Processed 56300 molecules...
# Processed 56400 molecules...
# Processed 56500 molecules...
# Processed 56600 molecules...
# Processed 56700 molecules...
# Processed 56800 molecules...
# Processed 56900 molecules...
# Processed 57000 molecules...
# Processed 57100 molecules...
# Processed 57200 molecules...
# Processed 57300 molecules...
# Processed 57400 molecules...
# Processed 57500 molecules...
# Processed 57600 molecules...
# Processed 57700 molecules...
# Processed 57800 molecules...
# Processed 57900 molecules...
# Processed 58000 molecules...
# Processed 58100 molecules...
# Processed 58200 molecules...
# Processed 58300 molecules...
# Processed 58400 molecules...
# Processed 58500 molecules...
# Processed 58600 molecules...
# Processed 58700 molecules...
# Processed 58800 molecules...
# Processed 58900 molecules...
# Processed 59000 molecules...
# Processed 59100 molecules...
# Processed 59200 molecules...
# Processed 59300 molecules...
# Processed 59400 molecules...
# Processed 59500 molecules...
# Processed 59600 molecules...
# Processed 59700 molecules...
# Processed 59800 molecules...
# Processed 59900 molecules...
# Processed 60000 molecules...
# Processed 60100 molecules...
# Processed 60200 molecules...
# Processed 60300 molecules...
# Processed 60400 molecules...
# Processed 60500 molecules...
# Processed 60600 molecules...
# Processed 60700 molecules...
# Processed 60800 molecules...
# Processed 60900 molecules...
# Processed 61000 molecules...
# Processed 61100 molecules...
# Processed 61200 molecules...
# Processed 61300 molecules...
# Processed 61400 molecules...
# Processed 61500 molecules...
# Processed 61600 molecules...
# Processed 61700 molecules...
# Processed 61800 molecules...
# Processed 61900 molecules...
# Processed 62000 molecules...
# Processed 62100 molecules...
# Processed 62200 molecules...
# Processed 62300 molecules...
# Processed 62400 molecules...
# Processed 62500 molecules...
# Processed 62600 molecules...
# Processed 62700 molecules...
# Processed 62800 molecules...
# Processed 62900 molecules...
# Processed 63000 molecules...
# Processed 63100 molecules...
# Processed 63200 molecules...
# Processed 63300 molecules...
# Processed 63400 molecules...
# Processed 63500 molecules...
# Processed 63600 molecules...
# Processed 63700 molecules...
# Processed 63800 molecules...
# Processed 63900 molecules...
# Processed 64000 molecules...
# Processed 64100 molecules...
# Processed 64200 molecules...
# Processed 64300 molecules...
# Processed 64400 molecules...
# Processed 64500 molecules...
# Processed 64600 molecules...
# Processed 64700 molecules...
# Processed 64800 molecules...
# Processed 64900 molecules...
# Processed 65000 molecules...
# Processed 65100 molecules...
# Processed 65200 molecules...
# Processed 65300 molecules...
# Processed 65400 molecules...
# Processed 65500 molecules...
# Processed 65600 molecules...
# Processed 65700 molecules...
# Processed 65800 molecules...
# Processed 65900 molecules...
# Processed 66000 molecules...
# Processed 66100 molecules...
# Processed 66200 molecules...
# Processed 66300 molecules...
# Processed 66400 molecules...
# Processed 66500 molecules...
# Processed 66600 molecules...
# Processed 66700 molecules...
# Processed 66800 molecules...
# Processed 66900 molecules...
# Processed 67000 molecules...
# Processed 67100 molecules...
# Processed 67200 molecules...
# Processed 67300 molecules...
# Processed 67400 molecules...
# Processed 67500 molecules...
# Processed 67600 molecules...
# Processed 67700 molecules...
# Processed 67800 molecules...
# Processed 67900 molecules...
# Processed 68000 molecules...
# Processed 68100 molecules...
# Processed 68200 molecules...
# Processed 68300 molecules...
# Processed 68400 molecules...
# Processed 68500 molecules...
# Processed 68600 molecules...
# Processed 68700 molecules...
# Processed 68800 molecules...
# Processed 68900 molecules...
# Processed 69000 molecules...
# Processed 69100 molecules...
# Processed 69200 molecules...
# Processed 69300 molecules...
# Processed 69400 molecules...
# Processed 69500 molecules...
# Processed 69600 molecules...
# Processed 69700 molecules...
# Processed 69800 molecules...
# Processed 69900 molecules...
# Processed 70000 molecules...
# Processed 70100 molecules...
# Processed 70200 molecules...
# Processed 70300 molecules...
# Processed 70400 molecules...
# Processed 70500 molecules...
# Processed 70600 molecules...
# Processed 70700 molecules...
# Processed 70800 molecules...
# Processed 70900 molecules...
# Processed 71000 molecules...
# Processed 71100 molecules...
# Processed 71200 molecules...
# Processed 71300 molecules...
# Processed 71400 molecules...
# Processed 71500 molecules...
# Processed 71600 molecules...
# Processed 71700 molecules...
# Processed 71800 molecules...
# Processed 71900 molecules...
# Processed 72000 molecules...
# Processed 72100 molecules...
# Processed 72200 molecules...
# Processed 72300 molecules...
# Processed 72400 molecules...
# Processed 72500 molecules...
# Processed 72600 molecules...
# Processed 72700 molecules...
# Processed 72800 molecules...
# Processed 72900 molecules...
# Processed 73000 molecules...
# Processed 73100 molecules...
# Processed 73200 molecules...
# Processed 73300 molecules...
# Processed 73400 molecules...
# Processed 73500 molecules...
# Processed 73600 molecules...
# Processed 73700 molecules...
# Processed 73800 molecules...
# Processed 73900 molecules...
# Processed 74000 molecules...
# Processed 74100 molecules...
# Processed 74200 molecules...
# Processed 74300 molecules...
# Processed 74400 molecules...
# Processed 74500 molecules...
# Processed 74600 molecules...
# Processed 74700 molecules...
# Processed 74800 molecules...
# Processed 74900 molecules...
# Processed 75000 molecules...
# Processed 75100 molecules...
# Processed 75200 molecules...
# Processed 75300 molecules...
# Processed 75400 molecules...
# Processed 75500 molecules...
# Processed 75600 molecules...
# Processed 75700 molecules...
# Processed 75800 molecules...
# Processed 75900 molecules...
# Processed 76000 molecules...
# Processed 76100 molecules...
# Processed 76200 molecules...
# Processed 76300 molecules...
# Processed 76400 molecules...
# Processed 76500 molecules...
# Processed 76600 molecules...
# Processed 76700 molecules...
# Processed 76800 molecules...
# Processed 76900 molecules...
# Processed 77000 molecules...
# Processed 77100 molecules...
# Processed 77200 molecules...
# Processed 77300 molecules...
# Processed 77400 molecules...
# Processed 77500 molecules...
# Processed 77600 molecules...
# Processed 77700 molecules...
# Processed 77800 molecules...
# Processed 77900 molecules...
# Processed 78000 molecules...
# Processed 78100 molecules...
# Processed 78200 molecules...
# Processed 78300 molecules...
# Processed 78400 molecules...
# Processed 78500 molecules...
# Processed 78600 molecules...
# Processed 78700 molecules...
# Processed 78800 molecules...
# Processed 78900 molecules...
# Processed 79000 molecules...
# Processed 79100 molecules...
# Processed 79200 molecules...
# Processed 79300 molecules...
# Processed 79400 molecules...
# Processed 79500 molecules...
# Processed 79600 molecules...
# Processed 79700 molecules...
# Processed 79800 molecules...
# Processed 79900 molecules...
# Processed 80000 molecules...
# Processed 80100 molecules...
# Processed 80200 molecules...
# Processed 80300 molecules...
# Processed 80400 molecules...
# Processed 80500 molecules...
# Processed 80600 molecules...
# Processed 80700 molecules...
# Processed 80800 molecules...
# Processed 80900 molecules...
# Processed 81000 molecules...
# Processed 81100 molecules...
# Processed 81200 molecules...
# Processed 81300 molecules...
# Processed 81400 molecules...
# Processed 81500 molecules...
# Processed 81600 molecules...
# Processed 81700 molecules...
# Processed 81800 molecules...
# Processed 81900 molecules...
# Processed 82000 molecules...
# Processed 82100 molecules...
# Processed 82200 molecules...
# Processed 82300 molecules...
# Processed 82400 molecules...
# Processed 82500 molecules...
# Processed 82600 molecules...
# Processed 82700 molecules...
# Processed 82800 molecules...
# Processed 82900 molecules...
# Processed 83000 molecules...
# Processed 83100 molecules...
# Processed 83200 molecules...
# Processed 83300 molecules...
# Processed 83400 molecules...
# Processed 83500 molecules...
# Processed 83600 molecules...
# Processed 83700 molecules...
# Processed 83800 molecules...
# Processed 83900 molecules...
# Processed 84000 molecules...
# Processed 84100 molecules...
# Processed 84200 molecules...
# Processed 84300 molecules...
# Processed 84400 molecules...
# Processed 84500 molecules...
# Processed 84600 molecules...
# Processed 84700 molecules...
# Processed 84800 molecules...
# Processed 84900 molecules...
# Processed 85000 molecules...
# Processed 85100 molecules...
# Processed 85200 molecules...
# Processed 85300 molecules...
# Processed 85400 molecules...
# Processed 85500 molecules...
# Processed 85600 molecules...
# Processed 85700 molecules...
# Processed 85800 molecules...
# Processed 85900 molecules...
# Processed 86000 molecules...
# Processed 86100 molecules...
# Processed 86200 molecules...
# Processed 86300 molecules...
# Processed 86400 molecules...
# Processed 86500 molecules...
# Processed 86600 molecules...
# Processed 86700 molecules...
# Processed 86800 molecules...
# Processed 86900 molecules...
# Processed 87000 molecules...
# Processed 87100 molecules...
# Processed 87200 molecules...
# Processed 87300 molecules...
# Processed 87400 molecules...
# Processed 87500 molecules...
# Processed 87600 molecules...
# Processed 87700 molecules...
# Processed 87800 molecules...
# Processed 87900 molecules...
# Processed 88000 molecules...
# Processed 88100 molecules...
# Processed 88200 molecules...
# Processed 88300 molecules...
# Processed 88400 molecules...
# Processed 88500 molecules...
# Processed 88600 molecules...
# Processed 88700 molecules...
# Processed 88800 molecules...
# Processed 88900 molecules...
# Processed 89000 molecules...
# Processed 89100 molecules...
# Processed 89200 molecules...
# Processed 89300 molecules...
# Processed 89400 molecules...
# Processed 89500 molecules...
# Processed 89600 molecules...
# Processed 89700 molecules...
# Processed 89800 molecules...
# Processed 89900 molecules...
# Processed 90000 molecules...
# Processed 90100 molecules...
# Processed 90200 molecules...
# Processed 90300 molecules...
# Processed 90400 molecules...
# Processed 90500 molecules...
# Processed 90600 molecules...
# Processed 90700 molecules...
# Processed 90800 molecules...
# Processed 90900 molecules...
# Processed 91000 molecules...
# Processed 91100 molecules...
# Processed 91200 molecules...
# Processed 91300 molecules...
# Processed 91400 molecules...
# Processed 91500 molecules...
# Processed 91600 molecules...
# Processed 91700 molecules...
# Processed 91800 molecules...
# Processed 91900 molecules...
# Processed 92000 molecules...
# Processed 92100 molecules...
# Processed 92200 molecules...
# Processed 92300 molecules...
# Processed 92400 molecules...
# Processed 92500 molecules...
# Processed 92600 molecules...
# Processed 92700 molecules...
# Processed 92800 molecules...
# Processed 92900 molecules...
# Processed 93000 molecules...
# Processed 93100 molecules...
# Processed 93200 molecules...
# Processed 93300 molecules...
# Processed 93400 molecules...
# Processed 93500 molecules...
# Processed 93600 molecules...
# Processed 93700 molecules...
# Processed 93800 molecules...
# Processed 93900 molecules...
# Processed 94000 molecules...
# Processed 94100 molecules...
# Processed 94200 molecules...
# Processed 94300 molecules...
# Processed 94400 molecules...
# Processed 94500 molecules...
# Processed 94600 molecules...
# Processed 94700 molecules...
# Processed 94800 molecules...
# Processed 94900 molecules...
# Processed 95000 molecules...
# Processed 95100 molecules...
# Processed 95200 molecules...
# Processed 95300 molecules...
# Processed 95400 molecules...
# Processed 95500 molecules...
# Processed 95600 molecules...
# Processed 95700 molecules...
# Processed 95800 molecules...
# Processed 95900 molecules...
# Processed 96000 molecules...
# Processed 96100 molecules...
# Processed 96200 molecules...
# Processed 96300 molecules...
# Processed 96400 molecules...
# Processed 96500 molecules...
# Processed 96600 molecules...
# Processed 96700 molecules...
# Processed 96800 molecules...
# Processed 96900 molecules...
# Processed 97000 molecules...
# Processed 97100 molecules...
# Processed 97200 molecules...
# Processed 97300 molecules...
# Processed 97400 molecules...
# Processed 97500 molecules...
# Processed 97600 molecules...
# Processed 97700 molecules...
# Processed 97800 molecules...
# Processed 97900 molecules...
# Processed 98000 molecules...
# Processed 98100 molecules...
# Processed 98200 molecules...
# Processed 98300 molecules...
# Processed 98400 molecules...
# Processed 98500 molecules...
# Processed 98600 molecules...
# Processed 98700 molecules...
# Processed 98800 molecules...
# Processed 98900 molecules...
# Processed 99000 molecules...
# Processed 99100 molecules...
# Processed 99200 molecules...
# Processed 99300 molecules...
# Processed 99400 molecules...
# Processed 99500 molecules...
# Processed 99600 molecules...
# Processed 99700 molecules...
# Processed 99800 molecules...
# Processed 99900 molecules...
# Processed 100000 molecules...
# Processed 100100 molecules...
# Processed 100200 molecules...
# Processed 100300 molecules...
# Processed 100400 molecules...
# Processed 100500 molecules...
# Processed 100600 molecules...
# Processed 100700 molecules...
# Processed 100800 molecules...
# Processed 100900 molecules...
# Processed 101000 molecules...
# Processed 101100 molecules...
# Processed 101200 molecules...
# Processed 101300 molecules...
# Processed 101400 molecules...
# Processed 101500 molecules...
# Processed 101600 molecules...
# Processed 101700 molecules...
# Processed 101800 molecules...
# Processed 101900 molecules...
# Processed 102000 molecules...
# Processed 102100 molecules...
# Processed 102200 molecules...
# Processed 102300 molecules...
# Processed 102400 molecules...
# Processed 102500 molecules...
# Processed 102600 molecules...
# Processed 102700 molecules...
# Processed 102800 molecules...
# Processed 102900 molecules...
# Processed 103000 molecules...
# Processed 103100 molecules...
# Processed 103200 molecules...
# Processed 103300 molecules...
# Processed 103400 molecules...
# Processed 103500 molecules...
# Processed 103600 molecules...
# Processed 103700 molecules...
# Processed 103800 molecules...
# Processed 103900 molecules...
# Processed 104000 molecules...
# Processed 104100 molecules...
# Processed 104200 molecules...
# Processed 104300 molecules...
# Processed 104400 molecules...
# Processed 104500 molecules...
# Processed 104600 molecules...
# Processed 104700 molecules...
# Processed 104800 molecules...
# Processed 104900 molecules...
# Processed 105000 molecules...
# Processed 105100 molecules...
# Processed 105200 molecules...
# Processed 105300 molecules...
# Processed 105400 molecules...
# Processed 105500 molecules...
# Processed 105600 molecules...
# Processed 105700 molecules...
# Processed 105800 molecules...
# Processed 105900 molecules...
# Processed 106000 molecules...
# Processed 106100 molecules...
# Processed 106200 molecules...
# Processed 106300 molecules...
# Processed 106400 molecules...
# Processed 106500 molecules...
# Processed 106600 molecules...
# Processed 106700 molecules...
# Processed 106800 molecules...
# Processed 106900 molecules...
# Processed 107000 molecules...
# Processed 107100 molecules...
# Processed 107200 molecules...
# Processed 107300 molecules...
# Processed 107400 molecules...
# Processed 107500 molecules...
# Processed 107600 molecules...
# Processed 107700 molecules...
# Processed 107800 molecules...
# Processed 107900 molecules...
# Processed 108000 molecules...
# Processed 108100 molecules...
# Processed 108200 molecules...
# Processed 108300 molecules...
# Processed 108400 molecules...
# Processed 108500 molecules...
# Processed 108600 molecules...
# Processed 108700 molecules...
# Processed 108800 molecules...
# Processed 108900 molecules...
# Processed 109000 molecules...
# Processed 109100 molecules...
# Processed 109200 molecules...
# Processed 109300 molecules...
# Processed 109400 molecules...
# Processed 109500 molecules...
# Processed 109600 molecules...
# Processed 109700 molecules...
# Processed 109800 molecules...
# Processed 109900 molecules...
# Processed 110000 molecules...
# Processed 110100 molecules...
# Processed 110200 molecules...
# Processed 110300 molecules...
# Processed 110400 molecules...
# Processed 110500 molecules...
# Processed 110600 molecules...
# Processed 110700 molecules...
# Processed 110800 molecules...
# Processed 110900 molecules...
# Processed 111000 molecules...
# Processed 111100 molecules...
# Processed 111200 molecules...
# Processed 111300 molecules...
# Processed 111400 molecules...
# Processed 111500 molecules...
# Processed 111600 molecules...
# Processed 111700 molecules...
# Processed 111800 molecules...
# Processed 111900 molecules...
# Processed 112000 molecules...
# Processed 112100 molecules...
# Processed 112200 molecules...
# Processed 112300 molecules...
# Processed 112400 molecules...
# Processed 112500 molecules...
# Processed 112600 molecules...
# Processed 112700 molecules...
# Processed 112800 molecules...
# Processed 112900 molecules...
# Processed 113000 molecules...
# Processed 113100 molecules...
# Processed 113200 molecules...
# Processed 113300 molecules...
# Processed 113400 molecules...
# Processed 113500 molecules...
# Processed 113600 molecules...
# Processed 113700 molecules...
# Processed 113800 molecules...
# Processed 113900 molecules...
# Processed 114000 molecules...
# Processed 114100 molecules...
# Processed 114200 molecules...
# Processed 114300 molecules...
# Processed 114400 molecules...
# Processed 114500 molecules...
# Processed 114600 molecules...
# Processed 114700 molecules...
# Processed 114800 molecules...
# Processed 114900 molecules...
# Processed 115000 molecules...
# Processed 115100 molecules...
# Processed 115200 molecules...
# Processed 115300 molecules...
# Processed 115400 molecules...
# Processed 115500 molecules...
# Processed 115600 molecules...
# Processed 115700 molecules...
# Processed 115800 molecules...
# Processed 115900 molecules...
# Processed 116000 molecules...
# Processed 116100 molecules...
# Processed 116200 molecules...
# Processed 116300 molecules...
# Processed 116400 molecules...
# Processed 116500 molecules...
# Processed 116600 molecules...
# Processed 116700 molecules...
# Processed 116800 molecules...
# Processed 116900 molecules...
# Processed 117000 molecules...
# Processed 117100 molecules...
# Processed 117200 molecules...
# Processed 117300 molecules...
# Processed 117400 molecules...
# Processed 117500 molecules...
# Processed 117600 molecules...
# Processed 117700 molecules...
# Processed 117800 molecules...
# Processed 117900 molecules...
# Processed 118000 molecules...
# Processed 118100 molecules...
# Processed 118200 molecules...
# Processed 118300 molecules...
# Processed 118400 molecules...
# Processed 118500 molecules...
# Processed 118600 molecules...
# Processed 118700 molecules...
# Processed 118800 molecules...
# Processed 118900 molecules...
# Processed 119000 molecules...
# Processed 119100 molecules...
# Processed 119200 molecules...
# Processed 119300 molecules...
# Processed 119400 molecules...
# Processed 119500 molecules...
# Processed 119600 molecules...
# Processed 119700 molecules...
# Processed 119800 molecules...
# Processed 119900 molecules...
# Processed 120000 molecules...
# Processed 120100 molecules...
# Processed 120200 molecules...
# Processed 120300 molecules...
# Processed 120400 molecules...
# Processed 120500 molecules...
# Processed 120600 molecules...
# Processed 120700 molecules...
# Processed 120800 molecules...
# Processed 120900 molecules...
# Processed 121000 molecules...
# Processed 121100 molecules...
# Processed 121200 molecules...
# Processed 121300 molecules...
# Processed 121400 molecules...
# Processed 121500 molecules...
# Processed 121600 molecules...
# Processed 121700 molecules...
# Processed 121800 molecules...
# Processed 121900 molecules...
# Processed 122000 molecules...
# Processed 122100 molecules...
# Processed 122200 molecules...
# Processed 122300 molecules...
# Processed 122400 molecules...
# Processed 122500 molecules...
# Processed 122600 molecules...
# Processed 122700 molecules...
# Processed 122800 molecules...
# Processed 122900 molecules...
# Processed 123000 molecules...
# Processed 123100 molecules...
# Processed 123200 molecules...
# Processed 123300 molecules...
# Processed 123400 molecules...
# Processed 123500 molecules...
# Processed 123600 molecules...
# Processed 123700 molecules...
# Processed 123800 molecules...
# Processed 123900 molecules...
# Processed 124000 molecules...
# Processed 124100 molecules...
# Processed 124200 molecules...
# Processed 124300 molecules...
# Processed 124400 molecules...
# Processed 124500 molecules...
# Processed 124600 molecules...
# Processed 124700 molecules...
# Processed 124800 molecules...
# Processed 124900 molecules...
# Processed 125000 molecules...
# Processed 125100 molecules...
# Processed 125200 molecules...
# Processed 125300 molecules...
# Processed 125400 molecules...
# Processed 125500 molecules...
# Processed 125600 molecules...
# Processed 125700 molecules...
# Processed 125800 molecules...
# Processed 125900 molecules...
# Processed 126000 molecules...
# Processed 126100 molecules...
# Processed 126200 molecules...
# Processed 126300 molecules...
# Processed 126400 molecules...
# Processed 126500 molecules...
# Processed 126600 molecules...
# Processed 126700 molecules...
# Processed 126800 molecules...
# Processed 126900 molecules...
# Processed 127000 molecules...
# Processed 127100 molecules...
# Processed 127200 molecules...
# Processed 127300 molecules...
# Processed 127400 molecules...
# Processed 127500 molecules...
# Processed 127600 molecules...
# Processed 127700 molecules...
# Processed 127800 molecules...
# Processed 127900 molecules...
# Processed 128000 molecules...
# Processed 128100 molecules...
# Processed 128200 molecules...
# Processed 128300 molecules...
# Processed 128400 molecules...
# Processed 128500 molecules...
# Processed 128600 molecules...
# Processed 128700 molecules...
# Processed 128800 molecules...
# Processed 128900 molecules...
# Processed 129000 molecules...
# Processed 129100 molecules...
# Processed 129200 molecules...
# Processed 129300 molecules...
# Processed 129400 molecules...
# Finished loading data!
# Adjacency tensor shape: (129427, 5, 12, 12)
# Feature tensor shape: (129427, 12, 6)
# DipoleMoment tensor shape: (129427,)

# %% [markdown]
# ## Build the Encoder and Decoder
#
# The Encoder takes as input a molecule's graph adjacency matrix and feature matrix.
# These features are processed via a Graph Convolution layer, then are flattened and
# processed by several Dense layers to derive `z_mean` and `log_var`, the
# latent-space representation of the molecule.
#
# **Graph Convolution layer**: The relational graph convolution layer implements
# non-linearly transformed neighbourhood aggregations. We can define these layers as
# follows:
#
# `H_hat**(l+1) = σ(D_hat**(-1) * A_hat * H_hat**(l+1) * W**(l))`
#
# Where `σ` denotes the non-linear transformation (commonly a ReLU activation), `A` the
# adjacency tensor, `H_hat**(l)` the feature tensor at the `l-th` layer, `D_hat**(-1)` the
# inverse diagonal degree tensor of `A_hat`, and `W_hat**(l)` the trainable weight tensor
# at the `l-th` layer. Specifically, for each bond type (relation), the degree tensor
# expresses, in the diagonal, the number of bonds attached to each atom.
#
# Source:
# [WGAN-GP with R-GCN for the generation of small molecular graphs](https://keras.io/examples/generative/wgan-graphs/))
#
# The Decoder takes as input the latent-space representation and predicts
# the graph adjacency matrix and feature matrix of the corresponding molecules.

# %%
def get_encoder(
    gconv_units, latent_dim, adjacency_shape, feature_shape, dense_units, dropout_rate
):
    adjacency = layers.Input(shape=adjacency_shape)
    features = layers.Input(shape=feature_shape)

    # Propagate through one or more graph convolutional layers
    features_transformed = features
    for units in gconv_units:
        features_transformed = RelationalGraphConvLayer(units)(
            [adjacency, features_transformed]
        )
    # Reduce 2-D representation of molecule to 1-D
    x = layers.GlobalAveragePooling1D()(features_transformed)

    # Propagate through one or more densely connected layers
    for units in dense_units:
        x = layers.Dense(units, activation="relu")(x)
        x = layers.Dropout(dropout_rate)(x)

    z_mean = layers.Dense(latent_dim, dtype="float32", name="z_mean")(x)
    log_var = layers.Dense(latent_dim, dtype="float32", name="log_var")(x)

    encoder = keras.Model([adjacency, features], [z_mean, log_var], name="encoder")

    return encoder


def get_decoder(dense_units, dropout_rate, latent_dim, adjacency_shape, feature_shape):
    latent_inputs = keras.Input(shape=(latent_dim,))

    x = latent_inputs
    for units in dense_units:
        x = layers.Dense(units, activation="tanh")(x)
        x = layers.Dropout(dropout_rate)(x)

    # Map outputs of previous layer (x) to [continuous] adjacency tensors (x_adjacency)
    x_adjacency = layers.Dense(np.prod(adjacency_shape))(x)
    x_adjacency = layers.Reshape(adjacency_shape)(x_adjacency)
    # Symmetrify tensors in the last two dimensions
    x_adjacency = (x_adjacency + ops.transpose(x_adjacency, (0, 1, 3, 2))) / 2
    x_adjacency = layers.Softmax(axis=1)(x_adjacency)

    # Map outputs of previous layer (x) to [continuous] feature tensors (x_features)
    x_features = layers.Dense(np.prod(feature_shape))(x)
    x_features = layers.Reshape(feature_shape)(x_features)
    x_features = layers.Softmax(axis=2)(x_features)

    decoder = keras.Model(
        latent_inputs, outputs=[x_adjacency, x_features], name="decoder"
    )

    return decoder

# %% [markdown]
# ## Build the Sampling layer

# %%
class Sampling(layers.Layer):
    def __init__(self, seed=None, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(seed)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch, dim = ops.shape(z_log_var)
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Build the VAE
#
# This model is trained to optimize four losses:
#
# * Categorical crossentropy
# * KL divergence loss
# * Property prediction loss
# * Graph loss (gradient penalty)
#
# The categorical crossentropy loss function measures the model's
# reconstruction accuracy. The Property prediction loss estimates the mean squared
# error between predicted and actual properties after running the latent representation
# through a property prediction model. The property
# prediction of the model is optimized via binary crossentropy. The gradient
# penalty is further guided by the model's property (QED) prediction.
#
# A gradient penalty is an alternative soft constraint on the
# 1-Lipschitz continuity as an improvement upon the gradient clipping scheme from the
# original neural network
# ("1-Lipschitz continuity" means that the norm of the gradient is at most 1 at every single
# point of the function).
# It adds a regularization term to the loss function.

# %%
class MoleculeGenerator(keras.Model):
    def __init__(self, encoder, decoder, max_len, seed=None, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.property_prediction_layer = layers.Dense(1)
        self.max_len = max_len
        self.seed_generator = keras.random.SeedGenerator(seed)
        self.sampling_layer = Sampling(seed=seed)

        self.train_total_loss_tracker = keras.metrics.Mean(name="train_total_loss")
        self.val_total_loss_tracker = keras.metrics.Mean(name="val_total_loss")

    def train_step(self, data):
        adjacency_tensor, feature_tensor, DipoleMoment_tensor = data[0]
        graph_real = [adjacency_tensor, feature_tensor]
        self.batch_size = ops.shape(DipoleMoment_tensor)[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, qed_pred, gen_adjacency, gen_features = self(
                graph_real, training=True
            )
            graph_generated = [gen_adjacency, gen_features]
            total_loss = self._compute_loss(
                z_log_var, z_mean, DipoleMoment_tensor, qed_pred, graph_real, graph_generated
            )

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.train_total_loss_tracker.update_state(total_loss)
        return {"loss": self.train_total_loss_tracker.result()}




    def _compute_loss(
        self, z_log_var, z_mean, DipoleMoment_true, DipoleMoment_pred, graph_real, graph_generated
    ):
        adjacency_real, features_real = graph_real
        adjacency_gen, features_gen = graph_generated

        adjacency_loss = ops.mean(
            ops.sum(
                keras.losses.categorical_crossentropy(
                    adjacency_real, adjacency_gen, axis=1
                ),
                axis=(1, 2),
            )
        )
        features_loss = ops.mean(
            ops.sum(
                keras.losses.categorical_crossentropy(features_real, features_gen),
                axis=(1),
            )
        )
        kl_loss = -0.5 * ops.sum(
            1 + z_log_var - z_mean**2 - ops.minimum(ops.exp(z_log_var), 1e6), 1
        )
        kl_loss = ops.mean(kl_loss)

        property_loss = keras.losses.mean_squared_error(DipoleMoment_true, DipoleMoment_pred)
        property_loss = ops.mean(property_loss)

        graph_loss = self._gradient_penalty(graph_real, graph_generated)

        return kl_loss + property_loss + graph_loss + adjacency_loss + features_loss

    def _gradient_penalty(self, graph_real, graph_generated):
        # Unpack graphs
        adjacency_real, features_real = graph_real
        adjacency_generated, features_generated = graph_generated

        # Generate interpolated graphs (adjacency_interp and features_interp)
        alpha = keras.random.uniform(shape=(self.batch_size,), seed=self.seed_generator)
        alpha = ops.reshape(alpha, (self.batch_size, 1, 1, 1))
        adjacency_interp = (adjacency_real * alpha) + (
            1.0 - alpha
        ) * adjacency_generated
        alpha = ops.reshape(alpha, (self.batch_size, 1, 1))
        features_interp = (features_real * alpha) + (1.0 - alpha) * features_generated

        # Compute the logits of interpolated graphs
        with tf.GradientTape() as tape:
            tape.watch(adjacency_interp)
            tape.watch(features_interp)
            _, _, logits, _, _ = self(
                [adjacency_interp, features_interp], training=True
            )

        # Compute the gradients with respect to the interpolated graphs
        grads = tape.gradient(logits, [adjacency_interp, features_interp])
        # Compute the gradient penalty
        grads_adjacency_penalty = (1 - ops.norm(grads[0], axis=1)) ** 2
        grads_features_penalty = (1 - ops.norm(grads[1], axis=2)) ** 2
        return ops.mean(
            ops.mean(grads_adjacency_penalty, axis=(-2, -1))
            + ops.mean(grads_features_penalty, axis=(-1))
        )

    def inference(self, batch_size):
        z = keras.random.normal(
            shape=(batch_size, LATENT_DIM), seed=self.seed_generator
        )
        reconstruction_adjacency, reconstruction_features = model.decoder.predict(z)
        # obtain one-hot encoded adjacency tensor
        adjacency = ops.argmax(reconstruction_adjacency, axis=1)
        adjacency = ops.one_hot(adjacency, num_classes=BOND_DIM, axis=1)
        # Remove potential self-loops from adjacency
        adjacency = adjacency * (1.0 - ops.eye(NUM_ATOMS, dtype="float32")[None, None])
        # obtain one-hot encoded feature tensor
        features = ops.argmax(reconstruction_features, axis=2)
        features = ops.one_hot(features, num_classes=ATOM_DIM, axis=2)
        return [
            graph_to_molecule([adjacency[i].numpy(), features[i].numpy()])
            for i in range(batch_size)
        ]

    def call(self, inputs):
        z_mean, log_var = self.encoder(inputs)
        z = self.sampling_layer([z_mean, log_var])

        gen_adjacency, gen_features = self.decoder(z)

        property_pred = self.property_prediction_layer(z_mean)

        return z_mean, log_var, property_pred, gen_adjacency, gen_features

# %% [markdown]
# ## Train the model

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage

def is_normal_alkane(mol):
    if mol is None:
        return False

    # Remove hydrogens and fragments
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False

    # Check formula
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or 'N' in formula or 'O' in formula or 'Cl' in formula or 'Br' in formula:
        return False

    # Check all atoms are sp3 carbon
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6:
            return False
        if atom.GetHybridization() != Chem.HybridizationType.SP3:
            return False
        if atom.GetDegree() > 4:
            return False

    # Acyclic
    if mol.GetRingInfo().NumRings() > 0:
        return False

    return True

from rdkit import Chem
from rdkit.Chem.rdmolops import GetMolFrags

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False

    # Reject if there are disconnected fragments
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False

    return True

# %%
# !wget https://raw.githubusercontent.com/rdkit/rdkit/master/Contrib/SA_Score/sascorer.py
# Out:
# --2025-06-26 12:13:23--  https://raw.githubusercontent.com/rdkit/rdkit/master/Contrib/SA_Score/sascorer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5913 (5.8K) [text/plain]
# Saving to: ‘sascorer.py’
#
# sascorer.py         100%[===================>]   5.77K  --.-KB/s    in 0s
#
# 2025-06-26 12:13:24 (87.5 MB/s) - ‘sascorer.py’ saved [5913/5913]

# %%
import sascorer  # after downloading the above

# %% [markdown]
# ## Inference
#
# We use our model to generate new valid molecules from different points of the latent space.

# %% [markdown]
# ### Generate unique Molecules with the model

# %%
vae_optimizer = keras.optimizers.Adam(learning_rate=1e-5)

encoder = get_encoder(
    gconv_units=[9],
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
    latent_dim=LATENT_DIM,
    dense_units=[512],
    dropout_rate=0.0,
)
decoder = get_decoder(
    dense_units=[128, 256, 512],
    dropout_rate=0.2,
    latent_dim=LATENT_DIM,
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
)

model = MoleculeGenerator(encoder, decoder, MAX_MOLSIZE)

model.compile(vae_optimizer)
history = model.fit([adjacency_tensor, feature_tensor, DipoleMoment_tensor], epochs=EPOCHS)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 135.6944
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 52.4598
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 51.4337
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 51.0439
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 50.7353
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 50.1761
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 49.5769
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 49.1987
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 48.7457
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 48.2505

# %% [markdown]
# ### Display latent space clusters with respect to molecular properties (QAE)

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage
def is_synthesizable(mol, threshold=5.0):
    try:
        sa_score = sascorer.calculateScore(mol)
        return sa_score <= threshold
    except:
        return False

def is_normal_alkane(mol):
    if mol is None:
        return False
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or any(x in formula for x in ['N', 'O', 'Cl', 'Br']):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6 or atom.GetHybridization() != Chem.HybridizationType.SP3 or atom.GetDegree() > 4:
            return False
    if mol.GetRingInfo().NumRings() > 0:
        return False
    return True

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    return True

# Set to store unique SMILES strings
unique_smiles = set()
all_valid_mols = []

# Generate and process molecules 50 times
for _ in range(50):
    molecules = model.inference(1000)
    for mol in molecules:
        if mol is not None and is_valid_molecule(mol) and not is_normal_alkane(mol) and is_synthesizable:
            try:
                smiles = Chem.MolToSmiles(mol, canonical=True)
                if smiles not in unique_smiles:
                    unique_smiles.add(smiles)
                    all_valid_mols.append(mol)
            except:
                continue

# Report
print(f"Total unique, valid, non-normal-alkane molecules generated: {len(unique_smiles)}")

# Optional: Display some of them
MolsToGridImage(all_valid_mols[:25], molsPerRow=5, subImgSize=(260, 160))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Total unique, valid, non-normal-alkane molecules generated: 771

# %% [markdown]
# #1,00,000

# %%
MAX_SAMPLES = 100000

# %%
adjacency_tensor, feature_tensor, DipoleMoment_tensor = [], [], []

for idx in range(len(df)):
    if len(adjacency_tensor) >= MAX_SAMPLES:
        break

    smiles = df.loc[idx]["SMILES"]
    DipoleMoment = df.loc[idx]["DipoleMoment"]

    try:
        adjacency, features = smiles_to_graph(smiles)

        if features.shape[0] > MAX_ATOMS:
            continue  # Skip large molecules

        # Pad to fixed size
        padded_adj = np.zeros((adjacency.shape[0], MAX_ATOMS, MAX_ATOMS), dtype=np.float32)
        padded_feat = np.zeros((MAX_ATOMS, features.shape[1]), dtype=np.float32)

        num_atoms = features.shape[0]
        padded_adj[:, :num_atoms, :num_atoms] = adjacency
        padded_feat[:num_atoms] = features

        adjacency_tensor.append(padded_adj)
        feature_tensor.append(padded_feat)
        DipoleMoment_tensor.append(DipoleMoment)

        if len(adjacency_tensor) % 100 == 0:
            print(f"Processed {len(adjacency_tensor)} molecules...")

    except Exception as e:
        print(f"Skipping idx={idx}, error: {e}")
        continue

adjacency_tensor = np.array(adjacency_tensor)
feature_tensor = np.array(feature_tensor)
DipoleMoment_tensor = np.array(DipoleMoment_tensor)

print("Finished loading data!")
print("Adjacency tensor shape:", adjacency_tensor.shape)
print("Feature tensor shape:", feature_tensor.shape)
print("DipoleMoment tensor shape:", DipoleMoment_tensor.shape)



class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype="float32",
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype="float32",
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = ops.matmul(adjacency, features[:, None])
        # Apply linear transformation
        x = ops.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = ops.sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)
# Out:
# Processed 100 molecules...
# Processed 200 molecules...
# Processed 300 molecules...
# Processed 400 molecules...
# Processed 500 molecules...
# Processed 600 molecules...
# Processed 700 molecules...
# Processed 800 molecules...
# Processed 900 molecules...
# Processed 1000 molecules...
# Processed 1100 molecules...
# Processed 1200 molecules...
# Processed 1300 molecules...
# Processed 1400 molecules...
# Processed 1500 molecules...
# Processed 1600 molecules...
# Processed 1700 molecules...
# Processed 1800 molecules...
# Processed 1900 molecules...
# Processed 2000 molecules...
# Processed 2100 molecules...
# Processed 2200 molecules...
# Processed 2300 molecules...
# Processed 2400 molecules...
# Processed 2500 molecules...
# Processed 2600 molecules...
# Processed 2700 molecules...
# Processed 2800 molecules...
# Processed 2900 molecules...
# Processed 3000 molecules...
# Processed 3100 molecules...
# Processed 3200 molecules...
# Processed 3300 molecules...
# Processed 3400 molecules...
# Processed 3500 molecules...
# Processed 3600 molecules...
# Processed 3700 molecules...
# Processed 3800 molecules...
# Processed 3900 molecules...
# Processed 4000 molecules...
# Processed 4100 molecules...
# Processed 4200 molecules...
# Processed 4300 molecules...
# Processed 4400 molecules...
# Processed 4500 molecules...
# Processed 4600 molecules...
# Processed 4700 molecules...
# Processed 4800 molecules...
# Processed 4900 molecules...
# Processed 5000 molecules...
# Processed 5100 molecules...
# Processed 5200 molecules...
# Processed 5300 molecules...
# Processed 5400 molecules...
# Processed 5500 molecules...
# Processed 5600 molecules...
# Processed 5700 molecules...
# Processed 5800 molecules...
# Processed 5900 molecules...
# Processed 6000 molecules...
# Processed 6100 molecules...
# Processed 6200 molecules...
# Processed 6300 molecules...
# Processed 6400 molecules...
# Processed 6500 molecules...
# Processed 6600 molecules...
# Processed 6700 molecules...
# Processed 6800 molecules...
# Processed 6900 molecules...
# Processed 7000 molecules...
# Processed 7100 molecules...
# Processed 7200 molecules...
# Processed 7300 molecules...
# Processed 7400 molecules...
# Processed 7500 molecules...
# Processed 7600 molecules...
# Processed 7700 molecules...
# Processed 7800 molecules...
# Processed 7900 molecules...
# Processed 8000 molecules...
# Processed 8100 molecules...
# Processed 8200 molecules...
# Processed 8300 molecules...
# Processed 8400 molecules...
# Processed 8500 molecules...
# Processed 8600 molecules...
# Processed 8700 molecules...
# Processed 8800 molecules...
# Processed 8900 molecules...
# Processed 9000 molecules...
# Processed 9100 molecules...
# Processed 9200 molecules...
# Processed 9300 molecules...
# Processed 9400 molecules...
# Processed 9500 molecules...
# Processed 9600 molecules...
# Processed 9700 molecules...
# Processed 9800 molecules...
# Processed 9900 molecules...
# Processed 10000 molecules...
# Processed 10100 molecules...
# Processed 10200 molecules...
# Processed 10300 molecules...
# Processed 10400 molecules...
# Processed 10500 molecules...
# Processed 10600 molecules...
# Processed 10700 molecules...
# Processed 10800 molecules...
# Processed 10900 molecules...
# Processed 11000 molecules...
# Processed 11100 molecules...
# Processed 11200 molecules...
# Processed 11300 molecules...
# Processed 11400 molecules...
# Processed 11500 molecules...
# Processed 11600 molecules...
# Processed 11700 molecules...
# Processed 11800 molecules...
# Processed 11900 molecules...
# Processed 12000 molecules...
# Processed 12100 molecules...
# Processed 12200 molecules...
# Processed 12300 molecules...
# Processed 12400 molecules...
# Processed 12500 molecules...
# Processed 12600 molecules...
# Processed 12700 molecules...
# Processed 12800 molecules...
# Processed 12900 molecules...
# Processed 13000 molecules...
# Processed 13100 molecules...
# Processed 13200 molecules...
# Processed 13300 molecules...
# Processed 13400 molecules...
# Processed 13500 molecules...
# Processed 13600 molecules...
# Processed 13700 molecules...
# Processed 13800 molecules...
# Processed 13900 molecules...
# Processed 14000 molecules...
# Processed 14100 molecules...
# Processed 14200 molecules...
# Processed 14300 molecules...
# Processed 14400 molecules...
# Processed 14500 molecules...
# Processed 14600 molecules...
# Processed 14700 molecules...
# Processed 14800 molecules...
# Processed 14900 molecules...
# Processed 15000 molecules...
# Processed 15100 molecules...
# Processed 15200 molecules...
# Processed 15300 molecules...
# Processed 15400 molecules...
# Processed 15500 molecules...
# Processed 15600 molecules...
# Processed 15700 molecules...
# Processed 15800 molecules...
# Processed 15900 molecules...
# Processed 16000 molecules...
# Processed 16100 molecules...
# Processed 16200 molecules...
# Processed 16300 molecules...
# Processed 16400 molecules...
# Processed 16500 molecules...
# Processed 16600 molecules...
# Processed 16700 molecules...
# Processed 16800 molecules...
# Processed 16900 molecules...
# Processed 17000 molecules...
# Processed 17100 molecules...
# Processed 17200 molecules...
# Processed 17300 molecules...
# Processed 17400 molecules...
# Processed 17500 molecules...
# Processed 17600 molecules...
# Processed 17700 molecules...
# Processed 17800 molecules...
# Processed 17900 molecules...
# Processed 18000 molecules...
# Processed 18100 molecules...
# Processed 18200 molecules...
# Processed 18300 molecules...
# Processed 18400 molecules...
# Processed 18500 molecules...
# Processed 18600 molecules...
# Processed 18700 molecules...
# Processed 18800 molecules...
# Processed 18900 molecules...
# Processed 19000 molecules...
# Processed 19100 molecules...
# Processed 19200 molecules...
# Processed 19300 molecules...
# Processed 19400 molecules...
# Processed 19500 molecules...
# Processed 19600 molecules...
# Processed 19700 molecules...
# Processed 19800 molecules...
# Processed 19900 molecules...
# Processed 20000 molecules...
# Processed 20100 molecules...
# Processed 20200 molecules...
# Processed 20300 molecules...
# Processed 20400 molecules...
# Processed 20500 molecules...
# Processed 20600 molecules...
# Processed 20700 molecules...
# Processed 20800 molecules...
# Processed 20900 molecules...
# Processed 21000 molecules...
# Processed 21100 molecules...
# Processed 21200 molecules...
# Processed 21300 molecules...
# Processed 21400 molecules...
# Processed 21500 molecules...
# Processed 21600 molecules...
# Processed 21700 molecules...
# Processed 21800 molecules...
# Processed 21900 molecules...
# Processed 22000 molecules...
# Processed 22100 molecules...
# Processed 22200 molecules...
# Processed 22300 molecules...
# Processed 22400 molecules...
# Processed 22500 molecules...
# Processed 22600 molecules...
# Processed 22700 molecules...
# Processed 22800 molecules...
# Processed 22900 molecules...
# Processed 23000 molecules...
# Processed 23100 molecules...
# Processed 23200 molecules...
# Processed 23300 molecules...
# Processed 23400 molecules...
# Processed 23500 molecules...
# Processed 23600 molecules...
# Processed 23700 molecules...
# Processed 23800 molecules...
# Processed 23900 molecules...
# Processed 24000 molecules...
# Processed 24100 molecules...
# Processed 24200 molecules...
# Processed 24300 molecules...
# Processed 24400 molecules...
# Processed 24500 molecules...
# Processed 24600 molecules...
# Processed 24700 molecules...
# Processed 24800 molecules...
# Processed 24900 molecules...
# Processed 25000 molecules...
# Processed 25100 molecules...
# Processed 25200 molecules...
# Processed 25300 molecules...
# Processed 25400 molecules...
# Processed 25500 molecules...
# Processed 25600 molecules...
# Processed 25700 molecules...
# Processed 25800 molecules...
# Processed 25900 molecules...
# Processed 26000 molecules...
# Processed 26100 molecules...
# Processed 26200 molecules...
# Processed 26300 molecules...
# Processed 26400 molecules...
# Processed 26500 molecules...
# Processed 26600 molecules...
# Processed 26700 molecules...
# Processed 26800 molecules...
# Processed 26900 molecules...
# Processed 27000 molecules...
# Processed 27100 molecules...
# Processed 27200 molecules...
# Processed 27300 molecules...
# Processed 27400 molecules...
# Processed 27500 molecules...
# Processed 27600 molecules...
# Processed 27700 molecules...
# Processed 27800 molecules...
# Processed 27900 molecules...
# Processed 28000 molecules...
# Processed 28100 molecules...
# Processed 28200 molecules...
# Processed 28300 molecules...
# Processed 28400 molecules...
# Processed 28500 molecules...
# Processed 28600 molecules...
# Processed 28700 molecules...
# Processed 28800 molecules...
# Processed 28900 molecules...
# Processed 29000 molecules...
# Processed 29100 molecules...
# Processed 29200 molecules...
# Processed 29300 molecules...
# Processed 29400 molecules...
# Processed 29500 molecules...
# Processed 29600 molecules...
# Processed 29700 molecules...
# Processed 29800 molecules...
# Processed 29900 molecules...
# Processed 30000 molecules...
# Processed 30100 molecules...
# Processed 30200 molecules...
# Processed 30300 molecules...
# Processed 30400 molecules...
# Processed 30500 molecules...
# Processed 30600 molecules...
# Processed 30700 molecules...
# Processed 30800 molecules...
# Processed 30900 molecules...
# Processed 31000 molecules...
# Processed 31100 molecules...
# Processed 31200 molecules...
# Processed 31300 molecules...
# Processed 31400 molecules...
# Processed 31500 molecules...
# Processed 31600 molecules...
# Processed 31700 molecules...
# Processed 31800 molecules...
# Processed 31900 molecules...
# Processed 32000 molecules...
# Processed 32100 molecules...
# Processed 32200 molecules...
# Processed 32300 molecules...
# Processed 32400 molecules...
# Processed 32500 molecules...
# Processed 32600 molecules...
# Processed 32700 molecules...
# Processed 32800 molecules...
# Processed 32900 molecules...
# Processed 33000 molecules...
# Processed 33100 molecules...
# Processed 33200 molecules...
# Processed 33300 molecules...
# Processed 33400 molecules...
# Processed 33500 molecules...
# Processed 33600 molecules...
# Processed 33700 molecules...
# Processed 33800 molecules...
# Processed 33900 molecules...
# Processed 34000 molecules...
# Processed 34100 molecules...
# Processed 34200 molecules...
# Processed 34300 molecules...
# Processed 34400 molecules...
# Processed 34500 molecules...
# Processed 34600 molecules...
# Processed 34700 molecules...
# Processed 34800 molecules...
# Processed 34900 molecules...
# Processed 35000 molecules...
# Processed 35100 molecules...
# Processed 35200 molecules...
# Processed 35300 molecules...
# Processed 35400 molecules...
# Processed 35500 molecules...
# Processed 35600 molecules...
# Processed 35700 molecules...
# Processed 35800 molecules...
# Processed 35900 molecules...
# Processed 36000 molecules...
# Processed 36100 molecules...
# Processed 36200 molecules...
# Processed 36300 molecules...
# Processed 36400 molecules...
# Processed 36500 molecules...
# Processed 36600 molecules...
# Processed 36700 molecules...
# Processed 36800 molecules...
# Processed 36900 molecules...
# Processed 37000 molecules...
# Processed 37100 molecules...
# Processed 37200 molecules...
# Processed 37300 molecules...
# Processed 37400 molecules...
# Processed 37500 molecules...
# Processed 37600 molecules...
# Processed 37700 molecules...
# Processed 37800 molecules...
# Processed 37900 molecules...
# Processed 38000 molecules...
# Processed 38100 molecules...
# Processed 38200 molecules...
# Processed 38300 molecules...
# Processed 38400 molecules...
# Processed 38500 molecules...
# Processed 38600 molecules...
# Processed 38700 molecules...
# Processed 38800 molecules...
# Processed 38900 molecules...
# Processed 39000 molecules...
# Processed 39100 molecules...
# Processed 39200 molecules...
# Processed 39300 molecules...
# Processed 39400 molecules...
# Processed 39500 molecules...
# Processed 39600 molecules...
# Processed 39700 molecules...
# Processed 39800 molecules...
# Processed 39900 molecules...
# Processed 40000 molecules...
# Processed 40100 molecules...
# Processed 40200 molecules...
# Processed 40300 molecules...
# Processed 40400 molecules...
# Processed 40500 molecules...
# Processed 40600 molecules...
# Processed 40700 molecules...
# Processed 40800 molecules...
# Processed 40900 molecules...
# Processed 41000 molecules...
# Processed 41100 molecules...
# Processed 41200 molecules...
# Processed 41300 molecules...
# Processed 41400 molecules...
# Processed 41500 molecules...
# Processed 41600 molecules...
# Processed 41700 molecules...
# Processed 41800 molecules...
# Processed 41900 molecules...
# Processed 42000 molecules...
# Processed 42100 molecules...
# Processed 42200 molecules...
# Processed 42300 molecules...
# Processed 42400 molecules...
# Processed 42500 molecules...
# Processed 42600 molecules...
# Processed 42700 molecules...
# Processed 42800 molecules...
# Processed 42900 molecules...
# Processed 43000 molecules...
# Processed 43100 molecules...
# Processed 43200 molecules...
# Processed 43300 molecules...
# Processed 43400 molecules...
# Processed 43500 molecules...
# Processed 43600 molecules...
# Processed 43700 molecules...
# Processed 43800 molecules...
# Processed 43900 molecules...
# Processed 44000 molecules...
# Processed 44100 molecules...
# Processed 44200 molecules...
# Processed 44300 molecules...
# Processed 44400 molecules...
# Processed 44500 molecules...
# Processed 44600 molecules...
# Processed 44700 molecules...
# Processed 44800 molecules...
# Processed 44900 molecules...
# Processed 45000 molecules...
# Processed 45100 molecules...
# Processed 45200 molecules...
# Processed 45300 molecules...
# Processed 45400 molecules...
# Processed 45500 molecules...
# Processed 45600 molecules...
# Processed 45700 molecules...
# Processed 45800 molecules...
# Processed 45900 molecules...
# Processed 46000 molecules...
# Processed 46100 molecules...
# Processed 46200 molecules...
# Processed 46300 molecules...
# Processed 46400 molecules...
# Processed 46500 molecules...
# Processed 46600 molecules...
# Processed 46700 molecules...
# Processed 46800 molecules...
# Processed 46900 molecules...
# Processed 47000 molecules...
# Processed 47100 molecules...
# Processed 47200 molecules...
# Processed 47300 molecules...
# Processed 47400 molecules...
# Processed 47500 molecules...
# Processed 47600 molecules...
# Processed 47700 molecules...
# Processed 47800 molecules...
# Processed 47900 molecules...
# Processed 48000 molecules...
# Processed 48100 molecules...
# Processed 48200 molecules...
# Processed 48300 molecules...
# Processed 48400 molecules...
# Processed 48500 molecules...
# Processed 48600 molecules...
# Processed 48700 molecules...
# Processed 48800 molecules...
# Processed 48900 molecules...
# Processed 49000 molecules...
# Processed 49100 molecules...
# Processed 49200 molecules...
# Processed 49300 molecules...
# Processed 49400 molecules...
# Processed 49500 molecules...
# Processed 49600 molecules...
# Processed 49700 molecules...
# Processed 49800 molecules...
# Processed 49900 molecules...
# Processed 50000 molecules...
# Processed 50100 molecules...
# Processed 50200 molecules...
# Processed 50300 molecules...
# Processed 50400 molecules...
# Processed 50500 molecules...
# Processed 50600 molecules...
# Processed 50700 molecules...
# Processed 50800 molecules...
# Processed 50900 molecules...
# Processed 51000 molecules...
# Processed 51100 molecules...
# Processed 51200 molecules...
# Processed 51300 molecules...
# Processed 51400 molecules...
# Processed 51500 molecules...
# Processed 51600 molecules...
# Processed 51700 molecules...
# Processed 51800 molecules...
# Processed 51900 molecules...
# Processed 52000 molecules...
# Processed 52100 molecules...
# Processed 52200 molecules...
# Processed 52300 molecules...
# Processed 52400 molecules...
# Processed 52500 molecules...
# Processed 52600 molecules...
# Processed 52700 molecules...
# Processed 52800 molecules...
# Processed 52900 molecules...
# Processed 53000 molecules...
# Processed 53100 molecules...
# Processed 53200 molecules...
# Processed 53300 molecules...
# Processed 53400 molecules...
# Processed 53500 molecules...
# Processed 53600 molecules...
# Processed 53700 molecules...
# Processed 53800 molecules...
# Processed 53900 molecules...
# Processed 54000 molecules...
# Processed 54100 molecules...
# Processed 54200 molecules...
# Processed 54300 molecules...
# Processed 54400 molecules...
# Processed 54500 molecules...
# Processed 54600 molecules...
# Processed 54700 molecules...
# Processed 54800 molecules...
# Processed 54900 molecules...
# Processed 55000 molecules...
# Processed 55100 molecules...
# Processed 55200 molecules...
# Processed 55300 molecules...
# Processed 55400 molecules...
# Processed 55500 molecules...
# Processed 55600 molecules...
# Processed 55700 molecules...
# Processed 55800 molecules...
# Processed 55900 molecules...
# Processed 56000 molecules...
# Processed 56100 molecules...
# Processed 56200 molecules...
# Processed 56300 molecules...
# Processed 56400 molecules...
# Processed 56500 molecules...
# Processed 56600 molecules...
# Processed 56700 molecules...
# Processed 56800 molecules...
# Processed 56900 molecules...
# Processed 57000 molecules...
# Processed 57100 molecules...
# Processed 57200 molecules...
# Processed 57300 molecules...
# Processed 57400 molecules...
# Processed 57500 molecules...
# Processed 57600 molecules...
# Processed 57700 molecules...
# Processed 57800 molecules...
# Processed 57900 molecules...
# Processed 58000 molecules...
# Processed 58100 molecules...
# Processed 58200 molecules...
# Processed 58300 molecules...
# Processed 58400 molecules...
# Processed 58500 molecules...
# Processed 58600 molecules...
# Processed 58700 molecules...
# Processed 58800 molecules...
# Processed 58900 molecules...
# Processed 59000 molecules...
# Processed 59100 molecules...
# Processed 59200 molecules...
# Processed 59300 molecules...
# Processed 59400 molecules...
# Processed 59500 molecules...
# Processed 59600 molecules...
# Processed 59700 molecules...
# Processed 59800 molecules...
# Processed 59900 molecules...
# Processed 60000 molecules...
# Processed 60100 molecules...
# Processed 60200 molecules...
# Processed 60300 molecules...
# Processed 60400 molecules...
# Processed 60500 molecules...
# Processed 60600 molecules...
# Processed 60700 molecules...
# Processed 60800 molecules...
# Processed 60900 molecules...
# Processed 61000 molecules...
# Processed 61100 molecules...
# Processed 61200 molecules...
# Processed 61300 molecules...
# Processed 61400 molecules...
# Processed 61500 molecules...
# Processed 61600 molecules...
# Processed 61700 molecules...
# Processed 61800 molecules...
# Processed 61900 molecules...
# Processed 62000 molecules...
# Processed 62100 molecules...
# Processed 62200 molecules...
# Processed 62300 molecules...
# Processed 62400 molecules...
# Processed 62500 molecules...
# Processed 62600 molecules...
# Processed 62700 molecules...
# Processed 62800 molecules...
# Processed 62900 molecules...
# Processed 63000 molecules...
# Processed 63100 molecules...
# Processed 63200 molecules...
# Processed 63300 molecules...
# Processed 63400 molecules...
# Processed 63500 molecules...
# Processed 63600 molecules...
# Processed 63700 molecules...
# Processed 63800 molecules...
# Processed 63900 molecules...
# Processed 64000 molecules...
# Processed 64100 molecules...
# Processed 64200 molecules...
# Processed 64300 molecules...
# Processed 64400 molecules...
# Processed 64500 molecules...
# Processed 64600 molecules...
# Processed 64700 molecules...
# Processed 64800 molecules...
# Processed 64900 molecules...
# Processed 65000 molecules...
# Processed 65100 molecules...
# Processed 65200 molecules...
# Processed 65300 molecules...
# Processed 65400 molecules...
# Processed 65500 molecules...
# Processed 65600 molecules...
# Processed 65700 molecules...
# Processed 65800 molecules...
# Processed 65900 molecules...
# Processed 66000 molecules...
# Processed 66100 molecules...
# Processed 66200 molecules...
# Processed 66300 molecules...
# Processed 66400 molecules...
# Processed 66500 molecules...
# Processed 66600 molecules...
# Processed 66700 molecules...
# Processed 66800 molecules...
# Processed 66900 molecules...
# Processed 67000 molecules...
# Processed 67100 molecules...
# Processed 67200 molecules...
# Processed 67300 molecules...
# Processed 67400 molecules...
# Processed 67500 molecules...
# Processed 67600 molecules...
# Processed 67700 molecules...
# Processed 67800 molecules...
# Processed 67900 molecules...
# Processed 68000 molecules...
# Processed 68100 molecules...
# Processed 68200 molecules...
# Processed 68300 molecules...
# Processed 68400 molecules...
# Processed 68500 molecules...
# Processed 68600 molecules...
# Processed 68700 molecules...
# Processed 68800 molecules...
# Processed 68900 molecules...
# Processed 69000 molecules...
# Processed 69100 molecules...
# Processed 69200 molecules...
# Processed 69300 molecules...
# Processed 69400 molecules...
# Processed 69500 molecules...
# Processed 69600 molecules...
# Processed 69700 molecules...
# Processed 69800 molecules...
# Processed 69900 molecules...
# Processed 70000 molecules...
# Processed 70100 molecules...
# Processed 70200 molecules...
# Processed 70300 molecules...
# Processed 70400 molecules...
# Processed 70500 molecules...
# Processed 70600 molecules...
# Processed 70700 molecules...
# Processed 70800 molecules...
# Processed 70900 molecules...
# Processed 71000 molecules...
# Processed 71100 molecules...
# Processed 71200 molecules...
# Processed 71300 molecules...
# Processed 71400 molecules...
# Processed 71500 molecules...
# Processed 71600 molecules...
# Processed 71700 molecules...
# Processed 71800 molecules...
# Processed 71900 molecules...
# Processed 72000 molecules...
# Processed 72100 molecules...
# Processed 72200 molecules...
# Processed 72300 molecules...
# Processed 72400 molecules...
# Processed 72500 molecules...
# Processed 72600 molecules...
# Processed 72700 molecules...
# Processed 72800 molecules...
# Processed 72900 molecules...
# Processed 73000 molecules...
# Processed 73100 molecules...
# Processed 73200 molecules...
# Processed 73300 molecules...
# Processed 73400 molecules...
# Processed 73500 molecules...
# Processed 73600 molecules...
# Processed 73700 molecules...
# Processed 73800 molecules...
# Processed 73900 molecules...
# Processed 74000 molecules...
# Processed 74100 molecules...
# Processed 74200 molecules...
# Processed 74300 molecules...
# Processed 74400 molecules...
# Processed 74500 molecules...
# Processed 74600 molecules...
# Processed 74700 molecules...
# Processed 74800 molecules...
# Processed 74900 molecules...
# Processed 75000 molecules...
# Processed 75100 molecules...
# Processed 75200 molecules...
# Processed 75300 molecules...
# Processed 75400 molecules...
# Processed 75500 molecules...
# Processed 75600 molecules...
# Processed 75700 molecules...
# Processed 75800 molecules...
# Processed 75900 molecules...
# Processed 76000 molecules...
# Processed 76100 molecules...
# Processed 76200 molecules...
# Processed 76300 molecules...
# Processed 76400 molecules...
# Processed 76500 molecules...
# Processed 76600 molecules...
# Processed 76700 molecules...
# Processed 76800 molecules...
# Processed 76900 molecules...
# Processed 77000 molecules...
# Processed 77100 molecules...
# Processed 77200 molecules...
# Processed 77300 molecules...
# Processed 77400 molecules...
# Processed 77500 molecules...
# Processed 77600 molecules...
# Processed 77700 molecules...
# Processed 77800 molecules...
# Processed 77900 molecules...
# Processed 78000 molecules...
# Processed 78100 molecules...
# Processed 78200 molecules...
# Processed 78300 molecules...
# Processed 78400 molecules...
# Processed 78500 molecules...
# Processed 78600 molecules...
# Processed 78700 molecules...
# Processed 78800 molecules...
# Processed 78900 molecules...
# Processed 79000 molecules...
# Processed 79100 molecules...
# Processed 79200 molecules...
# Processed 79300 molecules...
# Processed 79400 molecules...
# Processed 79500 molecules...
# Processed 79600 molecules...
# Processed 79700 molecules...
# Processed 79800 molecules...
# Processed 79900 molecules...
# Processed 80000 molecules...
# Processed 80100 molecules...
# Processed 80200 molecules...
# Processed 80300 molecules...
# Processed 80400 molecules...
# Processed 80500 molecules...
# Processed 80600 molecules...
# Processed 80700 molecules...
# Processed 80800 molecules...
# Processed 80900 molecules...
# Processed 81000 molecules...
# Processed 81100 molecules...
# Processed 81200 molecules...
# Processed 81300 molecules...
# Processed 81400 molecules...
# Processed 81500 molecules...
# Processed 81600 molecules...
# Processed 81700 molecules...
# Processed 81800 molecules...
# Processed 81900 molecules...
# Processed 82000 molecules...
# Processed 82100 molecules...
# Processed 82200 molecules...
# Processed 82300 molecules...
# Processed 82400 molecules...
# Processed 82500 molecules...
# Processed 82600 molecules...
# Processed 82700 molecules...
# Processed 82800 molecules...
# Processed 82900 molecules...
# Processed 83000 molecules...
# Processed 83100 molecules...
# Processed 83200 molecules...
# Processed 83300 molecules...
# Processed 83400 molecules...
# Processed 83500 molecules...
# Processed 83600 molecules...
# Processed 83700 molecules...
# Processed 83800 molecules...
# Processed 83900 molecules...
# Processed 84000 molecules...
# Processed 84100 molecules...
# Processed 84200 molecules...
# Processed 84300 molecules...
# Processed 84400 molecules...
# Processed 84500 molecules...
# Processed 84600 molecules...
# Processed 84700 molecules...
# Processed 84800 molecules...
# Processed 84900 molecules...
# Processed 85000 molecules...
# Processed 85100 molecules...
# Processed 85200 molecules...
# Processed 85300 molecules...
# Processed 85400 molecules...
# Processed 85500 molecules...
# Processed 85600 molecules...
# Processed 85700 molecules...
# Processed 85800 molecules...
# Processed 85900 molecules...
# Processed 86000 molecules...
# Processed 86100 molecules...
# Processed 86200 molecules...
# Processed 86300 molecules...
# Processed 86400 molecules...
# Processed 86500 molecules...
# Processed 86600 molecules...
# Processed 86700 molecules...
# Processed 86800 molecules...
# Processed 86900 molecules...
# Processed 87000 molecules...
# Processed 87100 molecules...
# Processed 87200 molecules...
# Processed 87300 molecules...
# Processed 87400 molecules...
# Processed 87500 molecules...
# Processed 87600 molecules...
# Processed 87700 molecules...
# Processed 87800 molecules...
# Processed 87900 molecules...
# Processed 88000 molecules...
# Processed 88100 molecules...
# Processed 88200 molecules...
# Processed 88300 molecules...
# Processed 88400 molecules...
# Processed 88500 molecules...
# Processed 88600 molecules...
# Processed 88700 molecules...
# Processed 88800 molecules...
# Processed 88900 molecules...
# Processed 89000 molecules...
# Processed 89100 molecules...
# Processed 89200 molecules...
# Processed 89300 molecules...
# Processed 89400 molecules...
# Processed 89500 molecules...
# Processed 89600 molecules...
# Processed 89700 molecules...
# Processed 89800 molecules...
# Processed 89900 molecules...
# Processed 90000 molecules...
# Processed 90100 molecules...
# Processed 90200 molecules...
# Processed 90300 molecules...
# Processed 90400 molecules...
# Processed 90500 molecules...
# Processed 90600 molecules...
# Processed 90700 molecules...
# Processed 90800 molecules...
# Processed 90900 molecules...
# Processed 91000 molecules...
# Processed 91100 molecules...
# Processed 91200 molecules...
# Processed 91300 molecules...
# Processed 91400 molecules...
# Processed 91500 molecules...
# Processed 91600 molecules...
# Processed 91700 molecules...
# Processed 91800 molecules...
# Processed 91900 molecules...
# Processed 92000 molecules...
# Processed 92100 molecules...
# Processed 92200 molecules...
# Processed 92300 molecules...
# Processed 92400 molecules...
# Processed 92500 molecules...
# Processed 92600 molecules...
# Processed 92700 molecules...
# Processed 92800 molecules...
# Processed 92900 molecules...
# Processed 93000 molecules...
# Processed 93100 molecules...
# Processed 93200 molecules...
# Processed 93300 molecules...
# Processed 93400 molecules...
# Processed 93500 molecules...
# Processed 93600 molecules...
# Processed 93700 molecules...
# Processed 93800 molecules...
# Processed 93900 molecules...
# Processed 94000 molecules...
# Processed 94100 molecules...
# Processed 94200 molecules...
# Processed 94300 molecules...
# Processed 94400 molecules...
# Processed 94500 molecules...
# Processed 94600 molecules...
# Processed 94700 molecules...
# Processed 94800 molecules...
# Processed 94900 molecules...
# Processed 95000 molecules...
# Processed 95100 molecules...
# Processed 95200 molecules...
# Processed 95300 molecules...
# Processed 95400 molecules...
# Processed 95500 molecules...
# Processed 95600 molecules...
# Processed 95700 molecules...
# Processed 95800 molecules...
# Processed 95900 molecules...
# Processed 96000 molecules...
# Processed 96100 molecules...
# Processed 96200 molecules...
# Processed 96300 molecules...
# Processed 96400 molecules...
# Processed 96500 molecules...
# Processed 96600 molecules...
# Processed 96700 molecules...
# Processed 96800 molecules...
# Processed 96900 molecules...
# Processed 97000 molecules...
# Processed 97100 molecules...
# Processed 97200 molecules...
# Processed 97300 molecules...
# Processed 97400 molecules...
# Processed 97500 molecules...
# Processed 97600 molecules...
# Processed 97700 molecules...
# Processed 97800 molecules...
# Processed 97900 molecules...
# Processed 98000 molecules...
# Processed 98100 molecules...
# Processed 98200 molecules...
# Processed 98300 molecules...
# Processed 98400 molecules...
# Processed 98500 molecules...
# Processed 98600 molecules...
# Processed 98700 molecules...
# Processed 98800 molecules...
# Processed 98900 molecules...
# Processed 99000 molecules...
# Processed 99100 molecules...
# Processed 99200 molecules...
# Processed 99300 molecules...
# Processed 99400 molecules...
# Processed 99500 molecules...
# Processed 99600 molecules...
# Processed 99700 molecules...
# Processed 99800 molecules...
# Processed 99900 molecules...
# Processed 100000 molecules...
# Finished loading data!
# Adjacency tensor shape: (100000, 5, 12, 12)
# Feature tensor shape: (100000, 12, 6)
# DipoleMoment tensor shape: (100000,)

# %%
vae_optimizer = keras.optimizers.Adam(learning_rate=1e-5)

encoder = get_encoder(
    gconv_units=[9],
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
    latent_dim=LATENT_DIM,
    dense_units=[512],
    dropout_rate=0.0,
)
decoder = get_decoder(
    dense_units=[128, 256, 512],
    dropout_rate=0.2,
    latent_dim=LATENT_DIM,
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
)

model = MoleculeGenerator(encoder, decoder, MAX_MOLSIZE)

model.compile(vae_optimizer)
history = model.fit([adjacency_tensor, feature_tensor, DipoleMoment_tensor], epochs=EPOCHS)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 143.2372
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 52.6169
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 51.5095
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 51.0688
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 50.4674
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 50.0345
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 49.5912
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 49.2673
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 48.7692
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 48.4699

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage
def is_synthesizable(mol, threshold=5.0):
    try:
        sa_score = sascorer.calculateScore(mol)
        return sa_score <= threshold
    except:
        return False

def is_normal_alkane(mol):
    if mol is None:
        return False
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or any(x in formula for x in ['N', 'O', 'Cl', 'Br']):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6 or atom.GetHybridization() != Chem.HybridizationType.SP3 or atom.GetDegree() > 4:
            return False
    if mol.GetRingInfo().NumRings() > 0:
        return False
    return True

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    return True

# Set to store unique SMILES strings
unique_smiles = set()
all_valid_mols = []

# Generate and process molecules 50 times
for _ in range(50):
    molecules = model.inference(1000)
    for mol in molecules:
        if mol is not None and is_valid_molecule(mol) and not is_normal_alkane(mol) and is_synthesizable:
            try:
                smiles = Chem.MolToSmiles(mol, canonical=True)
                if smiles not in unique_smiles:
                    unique_smiles.add(smiles)
                    all_valid_mols.append(mol)
            except:
                continue

# Report
print(f"Total unique, valid, non-normal-alkane molecules generated: {len(unique_smiles)}")

# Optional: Display some of them
MolsToGridImage(all_valid_mols[:25], molsPerRow=5, subImgSize=(260, 160))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Total unique, valid, non-normal-alkane molecules generated: 760

# %% [markdown]
# #50,000

# %%
MAX_SAMPLES = 50000

# %%
adjacency_tensor, feature_tensor, DipoleMoment_tensor = [], [], []

for idx in range(len(df)):
    if len(adjacency_tensor) >= MAX_SAMPLES:
        break

    smiles = df.loc[idx]["SMILES"]
    DipoleMoment = df.loc[idx]["DipoleMoment"]

    try:
        adjacency, features = smiles_to_graph(smiles)

        if features.shape[0] > MAX_ATOMS:
            continue  # Skip large molecules

        # Pad to fixed size
        padded_adj = np.zeros((adjacency.shape[0], MAX_ATOMS, MAX_ATOMS), dtype=np.float32)
        padded_feat = np.zeros((MAX_ATOMS, features.shape[1]), dtype=np.float32)

        num_atoms = features.shape[0]
        padded_adj[:, :num_atoms, :num_atoms] = adjacency
        padded_feat[:num_atoms] = features

        adjacency_tensor.append(padded_adj)
        feature_tensor.append(padded_feat)
        DipoleMoment_tensor.append(DipoleMoment)

        if len(adjacency_tensor) % 100 == 0:
            print(f"Processed {len(adjacency_tensor)} molecules...")

    except Exception as e:
        print(f"Skipping idx={idx}, error: {e}")
        continue

adjacency_tensor = np.array(adjacency_tensor)
feature_tensor = np.array(feature_tensor)
DipoleMoment_tensor = np.array(DipoleMoment_tensor)

print("Finished loading data!")
print("Adjacency tensor shape:", adjacency_tensor.shape)
print("Feature tensor shape:", feature_tensor.shape)
print("DipoleMoment tensor shape:", DipoleMoment_tensor.shape)



class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype="float32",
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype="float32",
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = ops.matmul(adjacency, features[:, None])
        # Apply linear transformation
        x = ops.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = ops.sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)
# Out:
# Processed 100 molecules...
# Processed 200 molecules...
# Processed 300 molecules...
# Processed 400 molecules...
# Processed 500 molecules...
# Processed 600 molecules...
# Processed 700 molecules...
# Processed 800 molecules...
# Processed 900 molecules...
# Processed 1000 molecules...
# Processed 1100 molecules...
# Processed 1200 molecules...
# Processed 1300 molecules...
# Processed 1400 molecules...
# Processed 1500 molecules...
# Processed 1600 molecules...
# Processed 1700 molecules...
# Processed 1800 molecules...
# Processed 1900 molecules...
# Processed 2000 molecules...
# Processed 2100 molecules...
# Processed 2200 molecules...
# Processed 2300 molecules...
# Processed 2400 molecules...
# Processed 2500 molecules...
# Processed 2600 molecules...
# Processed 2700 molecules...
# Processed 2800 molecules...
# Processed 2900 molecules...
# Processed 3000 molecules...
# Processed 3100 molecules...
# Processed 3200 molecules...
# Processed 3300 molecules...
# Processed 3400 molecules...
# Processed 3500 molecules...
# Processed 3600 molecules...
# Processed 3700 molecules...
# Processed 3800 molecules...
# Processed 3900 molecules...
# Processed 4000 molecules...
# Processed 4100 molecules...
# Processed 4200 molecules...
# Processed 4300 molecules...
# Processed 4400 molecules...
# Processed 4500 molecules...
# Processed 4600 molecules...
# Processed 4700 molecules...
# Processed 4800 molecules...
# Processed 4900 molecules...
# Processed 5000 molecules...
# Processed 5100 molecules...
# Processed 5200 molecules...
# Processed 5300 molecules...
# Processed 5400 molecules...
# Processed 5500 molecules...
# Processed 5600 molecules...
# Processed 5700 molecules...
# Processed 5800 molecules...
# Processed 5900 molecules...
# Processed 6000 molecules...
# Processed 6100 molecules...
# Processed 6200 molecules...
# Processed 6300 molecules...
# Processed 6400 molecules...
# Processed 6500 molecules...
# Processed 6600 molecules...
# Processed 6700 molecules...
# Processed 6800 molecules...
# Processed 6900 molecules...
# Processed 7000 molecules...
# Processed 7100 molecules...
# Processed 7200 molecules...
# Processed 7300 molecules...
# Processed 7400 molecules...
# Processed 7500 molecules...
# Processed 7600 molecules...
# Processed 7700 molecules...
# Processed 7800 molecules...
# Processed 7900 molecules...
# Processed 8000 molecules...
# Processed 8100 molecules...
# Processed 8200 molecules...
# Processed 8300 molecules...
# Processed 8400 molecules...
# Processed 8500 molecules...
# Processed 8600 molecules...
# Processed 8700 molecules...
# Processed 8800 molecules...
# Processed 8900 molecules...
# Processed 9000 molecules...
# Processed 9100 molecules...
# Processed 9200 molecules...
# Processed 9300 molecules...
# Processed 9400 molecules...
# Processed 9500 molecules...
# Processed 9600 molecules...
# Processed 9700 molecules...
# Processed 9800 molecules...
# Processed 9900 molecules...
# Processed 10000 molecules...
# Processed 10100 molecules...
# Processed 10200 molecules...
# Processed 10300 molecules...
# Processed 10400 molecules...
# Processed 10500 molecules...
# Processed 10600 molecules...
# Processed 10700 molecules...
# Processed 10800 molecules...
# Processed 10900 molecules...
# Processed 11000 molecules...
# Processed 11100 molecules...
# Processed 11200 molecules...
# Processed 11300 molecules...
# Processed 11400 molecules...
# Processed 11500 molecules...
# Processed 11600 molecules...
# Processed 11700 molecules...
# Processed 11800 molecules...
# Processed 11900 molecules...
# Processed 12000 molecules...
# Processed 12100 molecules...
# Processed 12200 molecules...
# Processed 12300 molecules...
# Processed 12400 molecules...
# Processed 12500 molecules...
# Processed 12600 molecules...
# Processed 12700 molecules...
# Processed 12800 molecules...
# Processed 12900 molecules...
# Processed 13000 molecules...
# Processed 13100 molecules...
# Processed 13200 molecules...
# Processed 13300 molecules...
# Processed 13400 molecules...
# Processed 13500 molecules...
# Processed 13600 molecules...
# Processed 13700 molecules...
# Processed 13800 molecules...
# Processed 13900 molecules...
# Processed 14000 molecules...
# Processed 14100 molecules...
# Processed 14200 molecules...
# Processed 14300 molecules...
# Processed 14400 molecules...
# Processed 14500 molecules...
# Processed 14600 molecules...
# Processed 14700 molecules...
# Processed 14800 molecules...
# Processed 14900 molecules...
# Processed 15000 molecules...
# Processed 15100 molecules...
# Processed 15200 molecules...
# Processed 15300 molecules...
# Processed 15400 molecules...
# Processed 15500 molecules...
# Processed 15600 molecules...
# Processed 15700 molecules...
# Processed 15800 molecules...
# Processed 15900 molecules...
# Processed 16000 molecules...
# Processed 16100 molecules...
# Processed 16200 molecules...
# Processed 16300 molecules...
# Processed 16400 molecules...
# Processed 16500 molecules...
# Processed 16600 molecules...
# Processed 16700 molecules...
# Processed 16800 molecules...
# Processed 16900 molecules...
# Processed 17000 molecules...
# Processed 17100 molecules...
# Processed 17200 molecules...
# Processed 17300 molecules...
# Processed 17400 molecules...
# Processed 17500 molecules...
# Processed 17600 molecules...
# Processed 17700 molecules...
# Processed 17800 molecules...
# Processed 17900 molecules...
# Processed 18000 molecules...
# Processed 18100 molecules...
# Processed 18200 molecules...
# Processed 18300 molecules...
# Processed 18400 molecules...
# Processed 18500 molecules...
# Processed 18600 molecules...
# Processed 18700 molecules...
# Processed 18800 molecules...
# Processed 18900 molecules...
# Processed 19000 molecules...
# Processed 19100 molecules...
# Processed 19200 molecules...
# Processed 19300 molecules...
# Processed 19400 molecules...
# Processed 19500 molecules...
# Processed 19600 molecules...
# Processed 19700 molecules...
# Processed 19800 molecules...
# Processed 19900 molecules...
# Processed 20000 molecules...
# Processed 20100 molecules...
# Processed 20200 molecules...
# Processed 20300 molecules...
# Processed 20400 molecules...
# Processed 20500 molecules...
# Processed 20600 molecules...
# Processed 20700 molecules...
# Processed 20800 molecules...
# Processed 20900 molecules...
# Processed 21000 molecules...
# Processed 21100 molecules...
# Processed 21200 molecules...
# Processed 21300 molecules...
# Processed 21400 molecules...
# Processed 21500 molecules...
# Processed 21600 molecules...
# Processed 21700 molecules...
# Processed 21800 molecules...
# Processed 21900 molecules...
# Processed 22000 molecules...
# Processed 22100 molecules...
# Processed 22200 molecules...
# Processed 22300 molecules...
# Processed 22400 molecules...
# Processed 22500 molecules...
# Processed 22600 molecules...
# Processed 22700 molecules...
# Processed 22800 molecules...
# Processed 22900 molecules...
# Processed 23000 molecules...
# Processed 23100 molecules...
# Processed 23200 molecules...
# Processed 23300 molecules...
# Processed 23400 molecules...
# Processed 23500 molecules...
# Processed 23600 molecules...
# Processed 23700 molecules...
# Processed 23800 molecules...
# Processed 23900 molecules...
# Processed 24000 molecules...
# Processed 24100 molecules...
# Processed 24200 molecules...
# Processed 24300 molecules...
# Processed 24400 molecules...
# Processed 24500 molecules...
# Processed 24600 molecules...
# Processed 24700 molecules...
# Processed 24800 molecules...
# Processed 24900 molecules...
# Processed 25000 molecules...
# Processed 25100 molecules...
# Processed 25200 molecules...
# Processed 25300 molecules...
# Processed 25400 molecules...
# Processed 25500 molecules...
# Processed 25600 molecules...
# Processed 25700 molecules...
# Processed 25800 molecules...
# Processed 25900 molecules...
# Processed 26000 molecules...
# Processed 26100 molecules...
# Processed 26200 molecules...
# Processed 26300 molecules...
# Processed 26400 molecules...
# Processed 26500 molecules...
# Processed 26600 molecules...
# Processed 26700 molecules...
# Processed 26800 molecules...
# Processed 26900 molecules...
# Processed 27000 molecules...
# Processed 27100 molecules...
# Processed 27200 molecules...
# Processed 27300 molecules...
# Processed 27400 molecules...
# Processed 27500 molecules...
# Processed 27600 molecules...
# Processed 27700 molecules...
# Processed 27800 molecules...
# Processed 27900 molecules...
# Processed 28000 molecules...
# Processed 28100 molecules...
# Processed 28200 molecules...
# Processed 28300 molecules...
# Processed 28400 molecules...
# Processed 28500 molecules...
# Processed 28600 molecules...
# Processed 28700 molecules...
# Processed 28800 molecules...
# Processed 28900 molecules...
# Processed 29000 molecules...
# Processed 29100 molecules...
# Processed 29200 molecules...
# Processed 29300 molecules...
# Processed 29400 molecules...
# Processed 29500 molecules...
# Processed 29600 molecules...
# Processed 29700 molecules...
# Processed 29800 molecules...
# Processed 29900 molecules...
# Processed 30000 molecules...
# Processed 30100 molecules...
# Processed 30200 molecules...
# Processed 30300 molecules...
# Processed 30400 molecules...
# Processed 30500 molecules...
# Processed 30600 molecules...
# Processed 30700 molecules...
# Processed 30800 molecules...
# Processed 30900 molecules...
# Processed 31000 molecules...
# Processed 31100 molecules...
# Processed 31200 molecules...
# Processed 31300 molecules...
# Processed 31400 molecules...
# Processed 31500 molecules...
# Processed 31600 molecules...
# Processed 31700 molecules...
# Processed 31800 molecules...
# Processed 31900 molecules...
# Processed 32000 molecules...
# Processed 32100 molecules...
# Processed 32200 molecules...
# Processed 32300 molecules...
# Processed 32400 molecules...
# Processed 32500 molecules...
# Processed 32600 molecules...
# Processed 32700 molecules...
# Processed 32800 molecules...
# Processed 32900 molecules...
# Processed 33000 molecules...
# Processed 33100 molecules...
# Processed 33200 molecules...
# Processed 33300 molecules...
# Processed 33400 molecules...
# Processed 33500 molecules...
# Processed 33600 molecules...
# Processed 33700 molecules...
# Processed 33800 molecules...
# Processed 33900 molecules...
# Processed 34000 molecules...
# Processed 34100 molecules...
# Processed 34200 molecules...
# Processed 34300 molecules...
# Processed 34400 molecules...
# Processed 34500 molecules...
# Processed 34600 molecules...
# Processed 34700 molecules...
# Processed 34800 molecules...
# Processed 34900 molecules...
# Processed 35000 molecules...
# Processed 35100 molecules...
# Processed 35200 molecules...
# Processed 35300 molecules...
# Processed 35400 molecules...
# Processed 35500 molecules...
# Processed 35600 molecules...
# Processed 35700 molecules...
# Processed 35800 molecules...
# Processed 35900 molecules...
# Processed 36000 molecules...
# Processed 36100 molecules...
# Processed 36200 molecules...
# Processed 36300 molecules...
# Processed 36400 molecules...
# Processed 36500 molecules...
# Processed 36600 molecules...
# Processed 36700 molecules...
# Processed 36800 molecules...
# Processed 36900 molecules...
# Processed 37000 molecules...
# Processed 37100 molecules...
# Processed 37200 molecules...
# Processed 37300 molecules...
# Processed 37400 molecules...
# Processed 37500 molecules...
# Processed 37600 molecules...
# Processed 37700 molecules...
# Processed 37800 molecules...
# Processed 37900 molecules...
# Processed 38000 molecules...
# Processed 38100 molecules...
# Processed 38200 molecules...
# Processed 38300 molecules...
# Processed 38400 molecules...
# Processed 38500 molecules...
# Processed 38600 molecules...
# Processed 38700 molecules...
# Processed 38800 molecules...
# Processed 38900 molecules...
# Processed 39000 molecules...
# Processed 39100 molecules...
# Processed 39200 molecules...
# Processed 39300 molecules...
# Processed 39400 molecules...
# Processed 39500 molecules...
# Processed 39600 molecules...
# Processed 39700 molecules...
# Processed 39800 molecules...
# Processed 39900 molecules...
# Processed 40000 molecules...
# Processed 40100 molecules...
# Processed 40200 molecules...
# Processed 40300 molecules...
# Processed 40400 molecules...
# Processed 40500 molecules...
# Processed 40600 molecules...
# Processed 40700 molecules...
# Processed 40800 molecules...
# Processed 40900 molecules...
# Processed 41000 molecules...
# Processed 41100 molecules...
# Processed 41200 molecules...
# Processed 41300 molecules...
# Processed 41400 molecules...
# Processed 41500 molecules...
# Processed 41600 molecules...
# Processed 41700 molecules...
# Processed 41800 molecules...
# Processed 41900 molecules...
# Processed 42000 molecules...
# Processed 42100 molecules...
# Processed 42200 molecules...
# Processed 42300 molecules...
# Processed 42400 molecules...
# Processed 42500 molecules...
# Processed 42600 molecules...
# Processed 42700 molecules...
# Processed 42800 molecules...
# Processed 42900 molecules...
# Processed 43000 molecules...
# Processed 43100 molecules...
# Processed 43200 molecules...
# Processed 43300 molecules...
# Processed 43400 molecules...
# Processed 43500 molecules...
# Processed 43600 molecules...
# Processed 43700 molecules...
# Processed 43800 molecules...
# Processed 43900 molecules...
# Processed 44000 molecules...
# Processed 44100 molecules...
# Processed 44200 molecules...
# Processed 44300 molecules...
# Processed 44400 molecules...
# Processed 44500 molecules...
# Processed 44600 molecules...
# Processed 44700 molecules...
# Processed 44800 molecules...
# Processed 44900 molecules...
# Processed 45000 molecules...
# Processed 45100 molecules...
# Processed 45200 molecules...
# Processed 45300 molecules...
# Processed 45400 molecules...
# Processed 45500 molecules...
# Processed 45600 molecules...
# Processed 45700 molecules...
# Processed 45800 molecules...
# Processed 45900 molecules...
# Processed 46000 molecules...
# Processed 46100 molecules...
# Processed 46200 molecules...
# Processed 46300 molecules...
# Processed 46400 molecules...
# Processed 46500 molecules...
# Processed 46600 molecules...
# Processed 46700 molecules...
# Processed 46800 molecules...
# Processed 46900 molecules...
# Processed 47000 molecules...
# Processed 47100 molecules...
# Processed 47200 molecules...
# Processed 47300 molecules...
# Processed 47400 molecules...
# Processed 47500 molecules...
# Processed 47600 molecules...
# Processed 47700 molecules...
# Processed 47800 molecules...
# Processed 47900 molecules...
# Processed 48000 molecules...
# Processed 48100 molecules...
# Processed 48200 molecules...
# Processed 48300 molecules...
# Processed 48400 molecules...
# Processed 48500 molecules...
# Processed 48600 molecules...
# Processed 48700 molecules...
# Processed 48800 molecules...
# Processed 48900 molecules...
# Processed 49000 molecules...
# Processed 49100 molecules...
# Processed 49200 molecules...
# Processed 49300 molecules...
# Processed 49400 molecules...
# Processed 49500 molecules...
# Processed 49600 molecules...
# Processed 49700 molecules...
# Processed 49800 molecules...
# Processed 49900 molecules...
# Processed 50000 molecules...
# Finished loading data!
# Adjacency tensor shape: (50000, 5, 12, 12)
# Feature tensor shape: (50000, 12, 6)
# DipoleMoment tensor shape: (50000,)

# %%
vae_optimizer = keras.optimizers.Adam(learning_rate=1e-5)

encoder = get_encoder(
    gconv_units=[9],
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
    latent_dim=LATENT_DIM,
    dense_units=[512],
    dropout_rate=0.0,
)
decoder = get_decoder(
    dense_units=[128, 256, 512],
    dropout_rate=0.2,
    latent_dim=LATENT_DIM,
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
)

model = MoleculeGenerator(encoder, decoder, MAX_MOLSIZE)

model.compile(vae_optimizer)
history = model.fit([adjacency_tensor, feature_tensor, DipoleMoment_tensor], epochs=EPOCHS)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 171.4876
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 57.0708
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 54.6438
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 53.8231
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 53.2747
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.7288
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.8175
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.5181
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.4459
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.0760

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage
def is_synthesizable(mol, threshold=5.0):
    try:
        sa_score = sascorer.calculateScore(mol)
        return sa_score <= threshold
    except:
        return False

def is_normal_alkane(mol):
    if mol is None:
        return False
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or any(x in formula for x in ['N', 'O', 'Cl', 'Br']):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6 or atom.GetHybridization() != Chem.HybridizationType.SP3 or atom.GetDegree() > 4:
            return False
    if mol.GetRingInfo().NumRings() > 0:
        return False
    return True

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    return True

# Set to store unique SMILES strings
unique_smiles = set()
all_valid_mols = []

# Generate and process molecules 50 times
for _ in range(50):
    molecules = model.inference(1000)
    for mol in molecules:
        if mol is not None and is_valid_molecule(mol) and not is_normal_alkane(mol) and is_synthesizable:
            try:
                smiles = Chem.MolToSmiles(mol, canonical=True)
                if smiles not in unique_smiles:
                    unique_smiles.add(smiles)
                    all_valid_mols.append(mol)
            except:
                continue

# Report
print(f"Total unique, valid, non-normal-alkane molecules generated: {len(unique_smiles)}")

# Optional: Display some of them
MolsToGridImage(all_valid_mols[:25], molsPerRow=5, subImgSize=(260, 160))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Total unique, valid, non-normal-alkane molecules generated: 985

# %% [markdown]
# ## Conclusion
#
# In this example, we combined model architectures from two papers,
# "Automatic chemical design using a data-driven continuous representation of
# molecules" from 2016 and the "MolGAN" paper from 2018. The former paper
# treats SMILES inputs as strings and seeks to generate molecule strings in SMILES format,
# while the later paper considers SMILES inputs as graphs (a combination of adjacency
# matrices and feature matrices) and seeks to generate molecules as graphs.
#
# This hybrid approach enables a new type of directed gradient-based search through chemical space.
#
# Example available on HuggingFace
#
# | Trained Model | Demo |
# | :--: | :--: |
# | [![Generic badge](https://img.shields.io/badge/%F0%9F%A4%97%20Model-molecule%20generation%20with%20VAE-black.svg)](https://huggingface.co/keras-io/drug-molecule-generation-with-VAE) | [![Generic badge](https://img.shields.io/badge/%F0%9F%A4%97%20Spaces-molecule%20generation%20with%20VAE-black.svg)](https://huggingface.co/spaces/keras-io/generating-drug-molecule-with-VAE) |

# %% [markdown]
# #25,000

# %%
MAX_SAMPLES = 25000

# %%
adjacency_tensor, feature_tensor, DipoleMoment_tensor = [], [], []

for idx in range(len(df)):
    if len(adjacency_tensor) >= MAX_SAMPLES:
        break

    smiles = df.loc[idx]["SMILES"]
    DipoleMoment = df.loc[idx]["DipoleMoment"]

    try:
        adjacency, features = smiles_to_graph(smiles)

        if features.shape[0] > MAX_ATOMS:
            continue  # Skip large molecules

        # Pad to fixed size
        padded_adj = np.zeros((adjacency.shape[0], MAX_ATOMS, MAX_ATOMS), dtype=np.float32)
        padded_feat = np.zeros((MAX_ATOMS, features.shape[1]), dtype=np.float32)

        num_atoms = features.shape[0]
        padded_adj[:, :num_atoms, :num_atoms] = adjacency
        padded_feat[:num_atoms] = features

        adjacency_tensor.append(padded_adj)
        feature_tensor.append(padded_feat)
        DipoleMoment_tensor.append(DipoleMoment)

        if len(adjacency_tensor) % 100 == 0:
            print(f"Processed {len(adjacency_tensor)} molecules...")

    except Exception as e:
        print(f"Skipping idx={idx}, error: {e}")
        continue

adjacency_tensor = np.array(adjacency_tensor)
feature_tensor = np.array(feature_tensor)
DipoleMoment_tensor = np.array(DipoleMoment_tensor)

print("Finished loading data!")
print("Adjacency tensor shape:", adjacency_tensor.shape)
print("Feature tensor shape:", feature_tensor.shape)
print("DipoleMoment tensor shape:", DipoleMoment_tensor.shape)



class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype="float32",
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype="float32",
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = ops.matmul(adjacency, features[:, None])
        # Apply linear transformation
        x = ops.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = ops.sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)
# Out:
# Processed 100 molecules...
# Processed 200 molecules...
# Processed 300 molecules...
# Processed 400 molecules...
# Processed 500 molecules...
# Processed 600 molecules...
# Processed 700 molecules...
# Processed 800 molecules...
# Processed 900 molecules...
# Processed 1000 molecules...
# Processed 1100 molecules...
# Processed 1200 molecules...
# Processed 1300 molecules...
# Processed 1400 molecules...
# Processed 1500 molecules...
# Processed 1600 molecules...
# Processed 1700 molecules...
# Processed 1800 molecules...
# Processed 1900 molecules...
# Processed 2000 molecules...
# Processed 2100 molecules...
# Processed 2200 molecules...
# Processed 2300 molecules...
# Processed 2400 molecules...
# Processed 2500 molecules...
# Processed 2600 molecules...
# Processed 2700 molecules...
# Processed 2800 molecules...
# Processed 2900 molecules...
# Processed 3000 molecules...
# Processed 3100 molecules...
# Processed 3200 molecules...
# Processed 3300 molecules...
# Processed 3400 molecules...
# Processed 3500 molecules...
# Processed 3600 molecules...
# Processed 3700 molecules...
# Processed 3800 molecules...
# Processed 3900 molecules...
# Processed 4000 molecules...
# Processed 4100 molecules...
# Processed 4200 molecules...
# Processed 4300 molecules...
# Processed 4400 molecules...
# Processed 4500 molecules...
# Processed 4600 molecules...
# Processed 4700 molecules...
# Processed 4800 molecules...
# Processed 4900 molecules...
# Processed 5000 molecules...
# Processed 5100 molecules...
# Processed 5200 molecules...
# Processed 5300 molecules...
# Processed 5400 molecules...
# Processed 5500 molecules...
# Processed 5600 molecules...
# Processed 5700 molecules...
# Processed 5800 molecules...
# Processed 5900 molecules...
# Processed 6000 molecules...
# Processed 6100 molecules...
# Processed 6200 molecules...
# Processed 6300 molecules...
# Processed 6400 molecules...
# Processed 6500 molecules...
# Processed 6600 molecules...
# Processed 6700 molecules...
# Processed 6800 molecules...
# Processed 6900 molecules...
# Processed 7000 molecules...
# Processed 7100 molecules...
# Processed 7200 molecules...
# Processed 7300 molecules...
# Processed 7400 molecules...
# Processed 7500 molecules...
# Processed 7600 molecules...
# Processed 7700 molecules...
# Processed 7800 molecules...
# Processed 7900 molecules...
# Processed 8000 molecules...
# Processed 8100 molecules...
# Processed 8200 molecules...
# Processed 8300 molecules...
# Processed 8400 molecules...
# Processed 8500 molecules...
# Processed 8600 molecules...
# Processed 8700 molecules...
# Processed 8800 molecules...
# Processed 8900 molecules...
# Processed 9000 molecules...
# Processed 9100 molecules...
# Processed 9200 molecules...
# Processed 9300 molecules...
# Processed 9400 molecules...
# Processed 9500 molecules...
# Processed 9600 molecules...
# Processed 9700 molecules...
# Processed 9800 molecules...
# Processed 9900 molecules...
# Processed 10000 molecules...
# Processed 10100 molecules...
# Processed 10200 molecules...
# Processed 10300 molecules...
# Processed 10400 molecules...
# Processed 10500 molecules...
# Processed 10600 molecules...
# Processed 10700 molecules...
# Processed 10800 molecules...
# Processed 10900 molecules...
# Processed 11000 molecules...
# Processed 11100 molecules...
# Processed 11200 molecules...
# Processed 11300 molecules...
# Processed 11400 molecules...
# Processed 11500 molecules...
# Processed 11600 molecules...
# Processed 11700 molecules...
# Processed 11800 molecules...
# Processed 11900 molecules...
# Processed 12000 molecules...
# Processed 12100 molecules...
# Processed 12200 molecules...
# Processed 12300 molecules...
# Processed 12400 molecules...
# Processed 12500 molecules...
# Processed 12600 molecules...
# Processed 12700 molecules...
# Processed 12800 molecules...
# Processed 12900 molecules...
# Processed 13000 molecules...
# Processed 13100 molecules...
# Processed 13200 molecules...
# Processed 13300 molecules...
# Processed 13400 molecules...
# Processed 13500 molecules...
# Processed 13600 molecules...
# Processed 13700 molecules...
# Processed 13800 molecules...
# Processed 13900 molecules...
# Processed 14000 molecules...
# Processed 14100 molecules...
# Processed 14200 molecules...
# Processed 14300 molecules...
# Processed 14400 molecules...
# Processed 14500 molecules...
# Processed 14600 molecules...
# Processed 14700 molecules...
# Processed 14800 molecules...
# Processed 14900 molecules...
# Processed 15000 molecules...
# Processed 15100 molecules...
# Processed 15200 molecules...
# Processed 15300 molecules...
# Processed 15400 molecules...
# Processed 15500 molecules...
# Processed 15600 molecules...
# Processed 15700 molecules...
# Processed 15800 molecules...
# Processed 15900 molecules...
# Processed 16000 molecules...
# Processed 16100 molecules...
# Processed 16200 molecules...
# Processed 16300 molecules...
# Processed 16400 molecules...
# Processed 16500 molecules...
# Processed 16600 molecules...
# Processed 16700 molecules...
# Processed 16800 molecules...
# Processed 16900 molecules...
# Processed 17000 molecules...
# Processed 17100 molecules...
# Processed 17200 molecules...
# Processed 17300 molecules...
# Processed 17400 molecules...
# Processed 17500 molecules...
# Processed 17600 molecules...
# Processed 17700 molecules...
# Processed 17800 molecules...
# Processed 17900 molecules...
# Processed 18000 molecules...
# Processed 18100 molecules...
# Processed 18200 molecules...
# Processed 18300 molecules...
# Processed 18400 molecules...
# Processed 18500 molecules...
# Processed 18600 molecules...
# Processed 18700 molecules...
# Processed 18800 molecules...
# Processed 18900 molecules...
# Processed 19000 molecules...
# Processed 19100 molecules...
# Processed 19200 molecules...
# Processed 19300 molecules...
# Processed 19400 molecules...
# Processed 19500 molecules...
# Processed 19600 molecules...
# Processed 19700 molecules...
# Processed 19800 molecules...
# Processed 19900 molecules...
# Processed 20000 molecules...
# Processed 20100 molecules...
# Processed 20200 molecules...
# Processed 20300 molecules...
# Processed 20400 molecules...
# Processed 20500 molecules...
# Processed 20600 molecules...
# Processed 20700 molecules...
# Processed 20800 molecules...
# Processed 20900 molecules...
# Processed 21000 molecules...
# Processed 21100 molecules...
# Processed 21200 molecules...
# Processed 21300 molecules...
# Processed 21400 molecules...
# Processed 21500 molecules...
# Processed 21600 molecules...
# Processed 21700 molecules...
# Processed 21800 molecules...
# Processed 21900 molecules...
# Processed 22000 molecules...
# Processed 22100 molecules...
# Processed 22200 molecules...
# Processed 22300 molecules...
# Processed 22400 molecules...
# Processed 22500 molecules...
# Processed 22600 molecules...
# Processed 22700 molecules...
# Processed 22800 molecules...
# Processed 22900 molecules...
# Processed 23000 molecules...
# Processed 23100 molecules...
# Processed 23200 molecules...
# Processed 23300 molecules...
# Processed 23400 molecules...
# Processed 23500 molecules...
# Processed 23600 molecules...
# Processed 23700 molecules...
# Processed 23800 molecules...
# Processed 23900 molecules...
# Processed 24000 molecules...
# Processed 24100 molecules...
# Processed 24200 molecules...
# Processed 24300 molecules...
# Processed 24400 molecules...
# Processed 24500 molecules...
# Processed 24600 molecules...
# Processed 24700 molecules...
# Processed 24800 molecules...
# Processed 24900 molecules...
# Processed 25000 molecules...
# Finished loading data!
# Adjacency tensor shape: (25000, 5, 12, 12)
# Feature tensor shape: (25000, 12, 6)
# DipoleMoment tensor shape: (25000,)

# %%
vae_optimizer = keras.optimizers.Adam(learning_rate=1e-5)

encoder = get_encoder(
    gconv_units=[9],
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
    latent_dim=LATENT_DIM,
    dense_units=[512],
    dropout_rate=0.0,
)
decoder = get_decoder(
    dense_units=[128, 256, 512],
    dropout_rate=0.2,
    latent_dim=LATENT_DIM,
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
)

model = MoleculeGenerator(encoder, decoder, MAX_MOLSIZE)

model.compile(vae_optimizer)
history = model.fit([adjacency_tensor, feature_tensor, DipoleMoment_tensor], epochs=EPOCHS)
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 226.1606
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 59.5642
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 52.8402
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 51.2080
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 50.3834
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 49.9726
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 49.7674
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 49.2488
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 49.0670
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 48.7361

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage
def is_synthesizable(mol, threshold=5.0):
    try:
        sa_score = sascorer.calculateScore(mol)
        return sa_score <= threshold
    except:
        return False

def is_normal_alkane(mol):
    if mol is None:
        return False
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or any(x in formula for x in ['N', 'O', 'Cl', 'Br']):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6 or atom.GetHybridization() != Chem.HybridizationType.SP3 or atom.GetDegree() > 4:
            return False
    if mol.GetRingInfo().NumRings() > 0:
        return False
    return True

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    return True

# Set to store unique SMILES strings
unique_smiles = set()
all_valid_mols = []

# Generate and process molecules 50 times
for _ in range(50):
    molecules = model.inference(1000)
    for mol in molecules:
        if mol is not None and is_valid_molecule(mol) and not is_normal_alkane(mol) and is_synthesizable:
            try:
                smiles = Chem.MolToSmiles(mol, canonical=True)
                if smiles not in unique_smiles:
                    unique_smiles.add(smiles)
                    all_valid_mols.append(mol)
            except:
                continue

# Report
print(f"Total unique, valid, non-normal-alkane molecules generated: {len(unique_smiles)}")

# Optional: Display some of them
MolsToGridImage(all_valid_mols[:25], molsPerRow=5, subImgSize=(260, 160))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Total unique, valid, non-normal-alkane molecules generated: 1330

# %% [markdown]
# #10,000

# %%
MAX_SAMPLES = 10000

# %%
adjacency_tensor, feature_tensor, DipoleMoment_tensor = [], [], []

for idx in range(len(df)):
    if len(adjacency_tensor) >= MAX_SAMPLES:
        break

    smiles = df.loc[idx]["SMILES"]
    DipoleMoment = df.loc[idx]["DipoleMoment"]

    try:
        adjacency, features = smiles_to_graph(smiles)

        if features.shape[0] > MAX_ATOMS:
            continue  # Skip large molecules

        # Pad to fixed size
        padded_adj = np.zeros((adjacency.shape[0], MAX_ATOMS, MAX_ATOMS), dtype=np.float32)
        padded_feat = np.zeros((MAX_ATOMS, features.shape[1]), dtype=np.float32)

        num_atoms = features.shape[0]
        padded_adj[:, :num_atoms, :num_atoms] = adjacency
        padded_feat[:num_atoms] = features

        adjacency_tensor.append(padded_adj)
        feature_tensor.append(padded_feat)
        DipoleMoment_tensor.append(DipoleMoment)

        if len(adjacency_tensor) % 100 == 0:
            print(f"Processed {len(adjacency_tensor)} molecules...")

    except Exception as e:
        print(f"Skipping idx={idx}, error: {e}")
        continue

adjacency_tensor = np.array(adjacency_tensor)
feature_tensor = np.array(feature_tensor)
DipoleMoment_tensor = np.array(DipoleMoment_tensor)

print("Finished loading data!")
print("Adjacency tensor shape:", adjacency_tensor.shape)
print("Feature tensor shape:", feature_tensor.shape)
print("DipoleMoment tensor shape:", DipoleMoment_tensor.shape)



class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype="float32",
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype="float32",
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = ops.matmul(adjacency, features[:, None])
        # Apply linear transformation
        x = ops.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = ops.sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)
# Out:
# Processed 100 molecules...
# Processed 200 molecules...
# Processed 300 molecules...
# Processed 400 molecules...
# Processed 500 molecules...
# Processed 600 molecules...
# Processed 700 molecules...
# Processed 800 molecules...
# Processed 900 molecules...
# Processed 1000 molecules...
# Processed 1100 molecules...
# Processed 1200 molecules...
# Processed 1300 molecules...
# Processed 1400 molecules...
# Processed 1500 molecules...
# Processed 1600 molecules...
# Processed 1700 molecules...
# Processed 1800 molecules...
# Processed 1900 molecules...
# Processed 2000 molecules...
# Processed 2100 molecules...
# Processed 2200 molecules...
# Processed 2300 molecules...
# Processed 2400 molecules...
# Processed 2500 molecules...
# Processed 2600 molecules...
# Processed 2700 molecules...
# Processed 2800 molecules...
# Processed 2900 molecules...
# Processed 3000 molecules...
# Processed 3100 molecules...
# Processed 3200 molecules...
# Processed 3300 molecules...
# Processed 3400 molecules...
# Processed 3500 molecules...
# Processed 3600 molecules...
# Processed 3700 molecules...
# Processed 3800 molecules...
# Processed 3900 molecules...
# Processed 4000 molecules...
# Processed 4100 molecules...
# Processed 4200 molecules...
# Processed 4300 molecules...
# Processed 4400 molecules...
# Processed 4500 molecules...
# Processed 4600 molecules...
# Processed 4700 molecules...
# Processed 4800 molecules...
# Processed 4900 molecules...
# Processed 5000 molecules...
# Processed 5100 molecules...
# Processed 5200 molecules...
# Processed 5300 molecules...
# Processed 5400 molecules...
# Processed 5500 molecules...
# Processed 5600 molecules...
# Processed 5700 molecules...
# Processed 5800 molecules...
# Processed 5900 molecules...
# Processed 6000 molecules...
# Processed 6100 molecules...
# Processed 6200 molecules...
# Processed 6300 molecules...
# Processed 6400 molecules...
# Processed 6500 molecules...
# Processed 6600 molecules...
# Processed 6700 molecules...
# Processed 6800 molecules...
# Processed 6900 molecules...
# Processed 7000 molecules...
# Processed 7100 molecules...
# Processed 7200 molecules...
# Processed 7300 molecules...
# Processed 7400 molecules...
# Processed 7500 molecules...
# Processed 7600 molecules...
# Processed 7700 molecules...
# Processed 7800 molecules...
# Processed 7900 molecules...
# Processed 8000 molecules...
# Processed 8100 molecules...
# Processed 8200 molecules...
# Processed 8300 molecules...
# Processed 8400 molecules...
# Processed 8500 molecules...
# Processed 8600 molecules...
# Processed 8700 molecules...
# Processed 8800 molecules...
# Processed 8900 molecules...
# Processed 9000 molecules...
# Processed 9100 molecules...
# Processed 9200 molecules...
# Processed 9300 molecules...
# Processed 9400 molecules...
# Processed 9500 molecules...
# Processed 9600 molecules...
# Processed 9700 molecules...
# Processed 9800 molecules...
# Processed 9900 molecules...
# Processed 10000 molecules...
# Finished loading data!
# Adjacency tensor shape: (10000, 5, 12, 12)
# Feature tensor shape: (10000, 12, 6)
# DipoleMoment tensor shape: (10000,)

# %%
vae_optimizer = keras.optimizers.Adam(learning_rate=1e-5)

encoder = get_encoder(
    gconv_units=[9],
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
    latent_dim=LATENT_DIM,
    dense_units=[512],
    dropout_rate=0.0,
)
decoder = get_decoder(
    dense_units=[128, 256, 512],
    dropout_rate=0.2,
    latent_dim=LATENT_DIM,
    adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
    feature_shape=(NUM_ATOMS, ATOM_DIM),
)

model = MoleculeGenerator(encoder, decoder, MAX_MOLSIZE)

model.compile(vae_optimizer)
history = model.fit([adjacency_tensor, feature_tensor, DipoleMoment_tensor], epochs=EPOCHS)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 264.3751
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156.9715
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.0001
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 56.0433
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 52.6525
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 50.9798
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.9815
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.2472
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 48.2999
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 48.3775

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit.Chem.Draw import MolsToGridImage
def is_synthesizable(mol, threshold=5.0):
    try:
        sa_score = sascorer.calculateScore(mol)
        return sa_score <= threshold
    except:
        return False

def is_normal_alkane(mol):
    if mol is None:
        return False
    mol = Chem.RemoveHs(mol)
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    formula = rdMolDescriptors.CalcMolFormula(mol)
    if not formula.startswith('C') or any(x in formula for x in ['N', 'O', 'Cl', 'Br']):
        return False
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() != 6 or atom.GetHybridization() != Chem.HybridizationType.SP3 or atom.GetDegree() > 4:
            return False
    if mol.GetRingInfo().NumRings() > 0:
        return False
    return True

def is_valid_molecule(mol):
    if mol is None:
        return False
    try:
        Chem.SanitizeMol(mol)
    except:
        return False
    fragments = GetMolFrags(mol, asMols=True)
    if len(fragments) > 1:
        return False
    return True

# Set to store unique SMILES strings
unique_smiles = set()
all_valid_mols = []

# Generate and process molecules 50 times
for _ in range(50):
    molecules = model.inference(1000)
    for mol in molecules:
        if mol is not None and is_valid_molecule(mol) and not is_normal_alkane(mol) and is_synthesizable:
            try:
                smiles = Chem.MolToSmiles(mol, canonical=True)
                if smiles not in unique_smiles:
                    unique_smiles.add(smiles)
                    all_valid_mols.append(mol)
            except:
                continue

# Report
print(f"Total unique, valid, non-normal-alkane molecules generated: {len(unique_smiles)}")

# Optional: Display some of them
MolsToGridImage(all_valid_mols[:25], molsPerRow=5, subImgSize=(260, 160))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Total unique, valid, non-normal-alkane molecules generated: 1568
